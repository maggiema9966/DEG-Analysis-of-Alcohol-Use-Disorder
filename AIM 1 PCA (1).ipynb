# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
from numpy import linalg as LA
import pandas as pd
from scipy import stats
from sklearn import preprocessing
import seaborn as sns

# %%
#gene expression dataframe
counts=pd.read_csv('countsNormLog.csv')

counts = counts.set_index('Gene')

# %%
#calculate variance for each row and add as new column
counts['variance'] = counts.var(axis=1)

#sort by variance
counts.sort_values(by='variance', ascending=False, inplace=True)
counts
#take top 10540 (approx 25%) of highest variance
counts25pca = counts.head(10540)

#delete variance column
counts25pca = counts25pca.drop('variance', axis = 1)

# %%
counts25pca
# Out:
#                       R15181  R15183_merged    R15207    R15274    R15394  \
# Gene
# ENSG00000259976.3  -2.519063      -2.558822  1.065913  0.788256 -2.603460
# ENSG00000260075.1   1.244365      -2.558822 -2.406844 -2.700295 -2.603460
# ENSG00000260186.5   0.093720       0.436813  0.931613  0.785427  1.042944
# ENSG00000134184.13  1.209290      -2.558822 -2.406844 -1.700295 -2.603460
# ENSG00000196273.8   0.300480       0.131374  0.826152  0.746863  0.632069
# ...                      ...            ...       ...       ...       ...
# ENSG00000286978.1  -2.519063      -2.558822 -2.406844 -1.223173 -1.603460
# ENSG00000215866.9  -2.519063      -1.081701 -1.105814 -1.223173 -2.603460
# ENSG00000287744.1  -2.519063      -1.558822 -1.105814 -1.700295 -2.603460
# ENSG00000234107.1  -1.519063      -1.081701 -1.105814 -1.700295 -1.603460
# ENSG00000226360.5  -2.519063      -1.257792 -0.929723 -1.399265 -2.603460
#
#                       R15395    R15396    R15399    R15402    R15428  ...  \
# Gene                                                                  ...
# ENSG00000259976.3  -2.671445 -2.639801  1.027146  0.906429 -2.495750  ...
# ENSG00000260075.1   1.412058 -2.639801  1.592462  1.223812  1.125426  ...
# ENSG00000260186.5   1.191283  1.050396  0.978503  1.208972  1.123343  ...
# ENSG00000134184.13  1.668801  1.236994 -1.452861  1.269472 -1.495750  ...
# ENSG00000196273.8   0.652838  0.791563  0.869359  0.769890  0.644129  ...
# ...                      ...       ...       ...       ...       ...  ...
# ENSG00000286978.1  -2.671445 -2.639801 -1.452861 -2.727039 -1.495750  ...
# ENSG00000215866.9  -2.671445 -1.037741 -0.674709 -0.948888 -1.018629  ...
# ENSG00000287744.1  -1.671445 -1.639801 -1.151831 -1.426009 -2.495750  ...
# ENSG00000234107.1  -0.893293 -1.162679 -0.498618 -1.028069 -0.893690  ...
# ENSG00000226360.5  -2.671445 -2.639801 -1.452861 -2.727039 -2.495750  ...
#
#                     R21863.1    R21864    R21866    R21868    R21869  \
# Gene
# ENSG00000259976.3  -2.555105  0.649831 -2.650464 -2.714947  0.879852
# ENSG00000260075.1  -0.953045 -2.622010 -2.650464 -2.714947 -2.649065
# ENSG00000260186.5  -1.555105 -2.622010 -1.650464 -2.714947 -1.649065
# ENSG00000134184.13 -2.555105 -1.622010  1.078700  1.092588 -1.649065
# ENSG00000196273.8  -2.555105 -2.622010 -2.650464 -2.714947 -2.649065
# ...                      ...       ...       ...       ...       ...
# ENSG00000286978.1  -2.555105 -2.622010 -2.650464 -2.714947 -2.649065
# ENSG00000215866.9  -1.555105 -1.320980 -1.173343 -1.112887 -1.649065
# ENSG00000287744.1  -2.555105 -2.622010 -1.349434 -2.714947 -2.649065
# ENSG00000234107.1  -1.555105 -1.320980 -1.349434 -1.413917 -0.950095
# ENSG00000226360.5  -2.555105 -1.320980 -2.650464 -2.714947 -2.649065
#
#                       R21870    R21871    R21872    R21873    R21874
# Gene
# ENSG00000259976.3  -2.377452 -2.574671 -2.563155 -2.685440  0.904112
# ENSG00000260075.1  -2.377452  0.901000 -0.058005 -2.685440 -2.738353
# ENSG00000260186.5  -2.377452 -1.273641 -1.086034 -2.685440 -2.738353
# ENSG00000134184.13  1.018748  1.107474 -2.563155  1.285371  1.132636
# ENSG00000196273.8  -2.377452 -2.574671 -2.563155 -2.685440 -2.738353
# ...                      ...       ...       ...       ...       ...
# ENSG00000286978.1  -2.377452 -2.574671 -2.563155 -2.685440 -2.738353
# ENSG00000215866.9  -2.377452 -0.671581 -2.563155 -0.986470 -1.039383
# ENSG00000287744.1  -2.377452 -1.273641 -2.563155 -2.685440 -2.738353
# ENSG00000234107.1  -1.076422 -1.097550 -1.563155 -0.731198 -1.136293
# ENSG00000226360.5  -2.377452 -1.574671 -2.563155 -2.685440 -2.738353
#
# [10540 rows x 194 columns]

# %%
#transpose selected counts data
transposecounts25pca = counts25pca.T.values
transposecounts25pca = preprocessing.StandardScaler().fit_transform(transposecounts25pca)

# %%
transposecounts25pca
# Out:
# array([[-0.94935853,  1.09106327,  0.43208136, ..., -0.60861304,
#         -0.65636725, -0.63736748],
#        [-0.97156626, -1.04072616,  0.65382278, ...,  1.17594623,
#          0.15646518,  1.70669767],
#        [ 1.05308538, -0.95553827,  0.97361243, ...,  2.01783849,
#          0.11165132,  2.31641261],
#        ...,
#        [-0.97398669,  0.36104958, -0.33039573, ..., -0.69055538,
#         -0.73831124, -0.71931182],
#        [-1.04229096, -1.11169924, -1.36409456, ..., -0.91781605,
#          0.80786964, -0.94657802],
#        [ 0.96270892, -1.14135812, -1.39829198, ..., -1.01615115,
#          0.05500636, -1.04491552]])

# %%
#import series matrix
annot=pd.read_csv('series matrix.csv')
annot = annot.set_index('!Sample_title')
annot
# Out:
#                                                           R15181  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015128
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 31.54
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 25
# !Sample_characteristics_ch1                             rin: 8.3
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: D05
# !Sample_characteristics_ch1                 brain number: Br1735
# !Sample_characteristics_ch1                    rnum_full: R15181
# !Sample_characteristics_ch1                    sv1: -0.229646051
# !Sample_characteristics_ch1                      sv2: 0.13859236
# !Sample_characteristics_ch1                      sv3: 0.07841074
# !Sample_characteristics_ch1                     sv4: 0.206190077
# !Sample_characteristics_ch1                      sv5: 0.03510265
# !Sample_characteristics_ch1                    sv6: -0.054085138
# !Sample_characteristics_ch1                     sv7: 0.192960398
# !Sample_characteristics_ch1                    sv8: -0.027965902
# !Sample_characteristics_ch1                     sv9: 0.173312723
# !Sample_characteristics_ch1                   sv10: -0.011115271
# !Sample_characteristics_ch1                    sv11: 0.064231982
# !Sample_characteristics_ch1                   sv12: -0.255029407
# !Sample_characteristics_ch1                     sv9: 0.173312723
# !Sample_characteristics_ch1                   sv10: -0.011115271
# !Sample_characteristics_ch1                    sv11: 0.064231982
# !Sample_characteristics_ch1                   sv12: -0.255029407
#
#                                                           R15183  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015129
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 35.25
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 16
# !Sample_characteristics_ch1                             rin: 7.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: H06
# !Sample_characteristics_ch1                 brain number: Br1995
# !Sample_characteristics_ch1             rnum_full: R15183_merged
# !Sample_characteristics_ch1                    sv1: -0.278660251
# !Sample_characteristics_ch1                     sv2: 0.216070294
# !Sample_characteristics_ch1                     sv3: 0.035467512
# !Sample_characteristics_ch1                    sv4: -0.057936977
# !Sample_characteristics_ch1                     sv5: 0.033479646
# !Sample_characteristics_ch1                     sv6: 0.040689475
# !Sample_characteristics_ch1                    sv7: -0.003116882
# !Sample_characteristics_ch1                     sv8: 0.168936507
# !Sample_characteristics_ch1                     sv9: 0.086255745
# !Sample_characteristics_ch1                    sv10: 0.065034378
# !Sample_characteristics_ch1                   sv11: -0.024624171
# !Sample_characteristics_ch1                    sv12: 0.042397304
# !Sample_characteristics_ch1                     sv9: 0.086255745
# !Sample_characteristics_ch1                    sv10: 0.065034378
# !Sample_characteristics_ch1                   sv11: -0.024624171
# !Sample_characteristics_ch1                    sv12: 0.042397304
#
#                                                           R15207  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015130
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 61.75
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 22.5
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: E07
# !Sample_characteristics_ch1                 brain number: Br5262
# !Sample_characteristics_ch1                    rnum_full: R15207
# !Sample_characteristics_ch1                     sv1: 0.008438168
# !Sample_characteristics_ch1                    sv2: -0.021005976
# !Sample_characteristics_ch1                     sv3: 0.025962544
# !Sample_characteristics_ch1                     sv4: -0.04310767
# !Sample_characteristics_ch1                     sv5: 0.120178949
# !Sample_characteristics_ch1                    sv6: -0.135392533
# !Sample_characteristics_ch1                     sv7: 0.106729625
# !Sample_characteristics_ch1                    sv8: -0.016302217
# !Sample_characteristics_ch1                     sv9: 0.248518998
# !Sample_characteristics_ch1                    sv10: 0.008790364
# !Sample_characteristics_ch1                    sv11: 0.022981964
# !Sample_characteristics_ch1                   sv12: -0.016178927
# !Sample_characteristics_ch1                     sv9: 0.248518998
# !Sample_characteristics_ch1                    sv10: 0.008790364
# !Sample_characteristics_ch1                    sv11: 0.022981964
# !Sample_characteristics_ch1                   sv12: -0.016178927
#
#                                                           R15274  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015131
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 38.39
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 41
# !Sample_characteristics_ch1                               rin: 8
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A10
# !Sample_characteristics_ch1                 brain number: Br1474
# !Sample_characteristics_ch1                    rnum_full: R15274
# !Sample_characteristics_ch1                     sv1: 0.044189388
# !Sample_characteristics_ch1                     sv2: 0.088108542
# !Sample_characteristics_ch1                    sv3: -0.017637236
# !Sample_characteristics_ch1                    sv4: -0.083645152
# !Sample_characteristics_ch1                    sv5: -0.178076113
# !Sample_characteristics_ch1                     sv6: 0.001464592
# !Sample_characteristics_ch1                     sv7: 0.188789719
# !Sample_characteristics_ch1                     sv8: 0.053503479
# !Sample_characteristics_ch1                    sv9: -0.005126922
# !Sample_characteristics_ch1                    sv10: 0.089448624
# !Sample_characteristics_ch1                    sv11: 0.210044746
# !Sample_characteristics_ch1                    sv12: 0.026841514
# !Sample_characteristics_ch1                    sv9: -0.005126922
# !Sample_characteristics_ch1                    sv10: 0.089448624
# !Sample_characteristics_ch1                    sv11: 0.210044746
# !Sample_characteristics_ch1                    sv12: 0.026841514
#
#                                                           R15394  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015132
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 46.79
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 21
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C07
# !Sample_characteristics_ch1                 brain number: Br2638
# !Sample_characteristics_ch1                    rnum_full: R15394
# !Sample_characteristics_ch1                      sv1: 0.06504724
# !Sample_characteristics_ch1                     sv2: 0.103257252
# !Sample_characteristics_ch1                    sv3: -0.007719585
# !Sample_characteristics_ch1                    sv4: -0.109417427
# !Sample_characteristics_ch1                     sv5: 0.140067633
# !Sample_characteristics_ch1                    sv6: -0.076831227
# !Sample_characteristics_ch1                     sv7: 0.191481655
# !Sample_characteristics_ch1                    sv8: -0.100146364
# !Sample_characteristics_ch1                     sv9: 0.033382681
# !Sample_characteristics_ch1                    sv10: 0.253915529
# !Sample_characteristics_ch1                   sv11: -0.036598844
# !Sample_characteristics_ch1                    sv12: 0.070337294
# !Sample_characteristics_ch1                     sv9: 0.033382681
# !Sample_characteristics_ch1                    sv10: 0.253915529
# !Sample_characteristics_ch1                   sv11: -0.036598844
# !Sample_characteristics_ch1                    sv12: 0.070337294
#
#                                                           R15395  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015133
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 52.69
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 23.5
# !Sample_characteristics_ch1                             rin: 7.7
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C01
# !Sample_characteristics_ch1                 brain number: Br5400
# !Sample_characteristics_ch1                    rnum_full: R15395
# !Sample_characteristics_ch1                     sv1: 0.068777173
# !Sample_characteristics_ch1                     sv2: 0.107345992
# !Sample_characteristics_ch1                      sv3: 0.06285047
# !Sample_characteristics_ch1                    sv4: -0.103439046
# !Sample_characteristics_ch1                    sv5: -0.109903519
# !Sample_characteristics_ch1                    sv6: -0.143630473
# !Sample_characteristics_ch1                     sv7: 0.200374278
# !Sample_characteristics_ch1                    sv8: -0.031331634
# !Sample_characteristics_ch1                     sv9: 0.001002766
# !Sample_characteristics_ch1                    sv10: 0.058719835
# !Sample_characteristics_ch1                    sv11: 0.094183124
# !Sample_characteristics_ch1                    sv12: 0.026086442
# !Sample_characteristics_ch1                     sv9: 0.001002766
# !Sample_characteristics_ch1                    sv10: 0.058719835
# !Sample_characteristics_ch1                    sv11: 0.094183124
# !Sample_characteristics_ch1                    sv12: 0.026086442
#
#                                                           R15396  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015134
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 38.99
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 32
# !Sample_characteristics_ch1                             rin: 7.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: C09
# !Sample_characteristics_ch1                 brain number: Br5459
# !Sample_characteristics_ch1                    rnum_full: R15396
# !Sample_characteristics_ch1                     sv1: 0.046323532
# !Sample_characteristics_ch1                     sv2: 0.000643698
# !Sample_characteristics_ch1                     sv3: 0.015659769
# !Sample_characteristics_ch1                    sv4: -0.007792991
# !Sample_characteristics_ch1                     sv5: 0.088717041
# !Sample_characteristics_ch1                    sv6: -0.058996178
# !Sample_characteristics_ch1                     sv7: 0.168468041
# !Sample_characteristics_ch1                     sv8: 0.206292703
# !Sample_characteristics_ch1                    sv9: -0.051335434
# !Sample_characteristics_ch1                    sv10: 0.019317293
# !Sample_characteristics_ch1                    sv11: 0.074310413
# !Sample_characteristics_ch1                    sv12: 0.025425311
# !Sample_characteristics_ch1                    sv9: -0.051335434
# !Sample_characteristics_ch1                    sv10: 0.019317293
# !Sample_characteristics_ch1                    sv11: 0.074310413
# !Sample_characteristics_ch1                    sv12: 0.025425311
#
#                                                           R15399  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015135
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 65.59057723
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 27
# !Sample_characteristics_ch1                             rin: 6.5
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B10
# !Sample_characteristics_ch1                 brain number: Br5864
# !Sample_characteristics_ch1                    rnum_full: R15399
# !Sample_characteristics_ch1                    sv1: -0.176622553
# !Sample_characteristics_ch1                    sv2: -0.258413183
# !Sample_characteristics_ch1                    sv3: -0.211797828
# !Sample_characteristics_ch1                    sv4: -0.114486883
# !Sample_characteristics_ch1                     sv5: 0.142546871
# !Sample_characteristics_ch1                    sv6: -0.138818262
# !Sample_characteristics_ch1                     sv7: 0.055849332
# !Sample_characteristics_ch1                    sv8: -0.059027088
# !Sample_characteristics_ch1                    sv9: -0.208278414
# !Sample_characteristics_ch1                   sv10: -0.001963668
# !Sample_characteristics_ch1                    sv11: 0.034595176
# !Sample_characteristics_ch1                   sv12: -0.069664972
# !Sample_characteristics_ch1                    sv9: -0.208278414
# !Sample_characteristics_ch1                   sv10: -0.001963668
# !Sample_characteristics_ch1                    sv11: 0.034595176
# !Sample_characteristics_ch1                   sv12: -0.069664972
#
#                                                           R15402  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015136
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 52.92
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 28
# !Sample_characteristics_ch1                             rin: 7.6
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: E06
# !Sample_characteristics_ch1                 brain number: Br5368
# !Sample_characteristics_ch1                    rnum_full: R15402
# !Sample_characteristics_ch1                     sv1: 0.073570839
# !Sample_characteristics_ch1                     sv2: 0.069655361
# !Sample_characteristics_ch1                     sv3: 0.092511005
# !Sample_characteristics_ch1                    sv4: -0.064893341
# !Sample_characteristics_ch1                     sv5: 0.115461612
# !Sample_characteristics_ch1                    sv6: -0.024157891
# !Sample_characteristics_ch1                     sv7: 0.116666182
# !Sample_characteristics_ch1                     sv8: 0.015519259
# !Sample_characteristics_ch1                    sv9: -0.133853998
# !Sample_characteristics_ch1                    sv10: 0.107523381
# !Sample_characteristics_ch1                     sv11: 0.01286849
# !Sample_characteristics_ch1                    sv12: 0.100814481
# !Sample_characteristics_ch1                    sv9: -0.133853998
# !Sample_characteristics_ch1                    sv10: 0.107523381
# !Sample_characteristics_ch1                     sv11: 0.01286849
# !Sample_characteristics_ch1                    sv12: 0.100814481
#
#                                                           R15428  ...  \
# !Sample_title                                                     ...
# !Sample_geo_accession                                 GSM8015137  ...
# !Sample_source_name_ch1                        Nucleus Accumbens  ...
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens  ...
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control  ...
# !Sample_characteristics_ch1                               Sex: M  ...
# !Sample_characteristics_ch1                      agedeath: 43.11  ...
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0  ...
# !Sample_characteristics_ch1     current smoker at death: Control  ...
# !Sample_characteristics_ch1                              pmi: 16  ...
# !Sample_characteristics_ch1                               rin: 7  ...
# !Sample_characteristics_ch1                      sample plate: 1  ...
# !Sample_characteristics_ch1                     sample well: C04  ...
# !Sample_characteristics_ch1                 brain number: Br5829  ...
# !Sample_characteristics_ch1                    rnum_full: R15428  ...
# !Sample_characteristics_ch1                    sv1: -0.016555083  ...
# !Sample_characteristics_ch1                    sv2: -0.013719968  ...
# !Sample_characteristics_ch1                     sv3: 0.177913849  ...
# !Sample_characteristics_ch1                    sv4: -0.073783129  ...
# !Sample_characteristics_ch1                     sv5: 0.107973092  ...
# !Sample_characteristics_ch1                    sv6: -0.015207092  ...
# !Sample_characteristics_ch1                     sv7: 0.102996227  ...
# !Sample_characteristics_ch1                     sv8: 0.004263393  ...
# !Sample_characteristics_ch1                    sv9: -0.187991496  ...
# !Sample_characteristics_ch1                    sv10: 0.180577707  ...
# !Sample_characteristics_ch1                   sv11: -0.067369302  ...
# !Sample_characteristics_ch1                    sv12: 0.034761337  ...
# !Sample_characteristics_ch1                    sv9: -0.187991496  ...
# !Sample_characteristics_ch1                    sv10: 0.180577707  ...
# !Sample_characteristics_ch1                   sv11: -0.067369302  ...
# !Sample_characteristics_ch1                    sv12: 0.034761337  ...
#
#                                                           R21863  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015312
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 37.42379649
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 33
# !Sample_characteristics_ch1                     rin: 7.497769295
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: B05
# !Sample_characteristics_ch1                 brain number: Br3925
# !Sample_characteristics_ch1                  rnum_full: R21863_1
# !Sample_characteristics_ch1                    sv1: -0.107503745
# !Sample_characteristics_ch1                     sv2: 0.089097193
# !Sample_characteristics_ch1                     sv3: 0.068016747
# !Sample_characteristics_ch1                     sv4: 0.022182646
# !Sample_characteristics_ch1                     sv5: 0.013130758
# !Sample_characteristics_ch1                     sv6: 0.095584713
# !Sample_characteristics_ch1                     sv7: 0.017436871
# !Sample_characteristics_ch1                     sv8: 0.058732866
# !Sample_characteristics_ch1                     sv9: 0.184997306
# !Sample_characteristics_ch1                   sv10: -0.185306802
# !Sample_characteristics_ch1                   sv11: -0.125824471
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.184997306
# !Sample_characteristics_ch1                   sv10: -0.185306802
# !Sample_characteristics_ch1                   sv11: -0.125824471
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21864  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015313
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 44.77481177
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 23.5
# !Sample_characteristics_ch1                       rin: 7.6541342
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: F05
# !Sample_characteristics_ch1                 brain number: Br3953
# !Sample_characteristics_ch1                    rnum_full: R21864
# !Sample_characteristics_ch1                    sv1: -0.110342856
# !Sample_characteristics_ch1                     sv2: 0.006809833
# !Sample_characteristics_ch1                    sv3: -0.127752187
# !Sample_characteristics_ch1                    sv4: -0.082172681
# !Sample_characteristics_ch1                    sv5: -0.200186512
# !Sample_characteristics_ch1                     sv6: 0.016950482
# !Sample_characteristics_ch1                    sv7: -0.150901672
# !Sample_characteristics_ch1                    sv8: -0.072879542
# !Sample_characteristics_ch1                     sv9: 0.014725284
# !Sample_characteristics_ch1                   sv10: -0.003110154
# !Sample_characteristics_ch1                   sv11: -0.146179861
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.014725284
# !Sample_characteristics_ch1                   sv10: -0.003110154
# !Sample_characteristics_ch1                   sv11: -0.146179861
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21866  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015314
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 64.26009582
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 22
# !Sample_characteristics_ch1                     rin: 7.512599528
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: D01
# !Sample_characteristics_ch1                 brain number: Br6393
# !Sample_characteristics_ch1                    rnum_full: R21866
# !Sample_characteristics_ch1                     sv1: 0.012575385
# !Sample_characteristics_ch1                    sv2: -0.001294275
# !Sample_characteristics_ch1                     sv3: 0.064167682
# !Sample_characteristics_ch1                    sv4: -0.009037275
# !Sample_characteristics_ch1                    sv5: -0.003742677
# !Sample_characteristics_ch1                     sv6: 0.033805367
# !Sample_characteristics_ch1                     sv7: -0.04244638
# !Sample_characteristics_ch1                     sv8: 0.055603272
# !Sample_characteristics_ch1                    sv9: -0.022571642
# !Sample_characteristics_ch1                   sv10: -0.021176236
# !Sample_characteristics_ch1                   sv11: -0.005320233
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.022571642
# !Sample_characteristics_ch1                   sv10: -0.021176236
# !Sample_characteristics_ch1                   sv11: -0.005320233
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21868  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015315
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 57.05692448
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 37.5
# !Sample_characteristics_ch1                     rin: 7.140684806
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A02
# !Sample_characteristics_ch1                 brain number: Br8408
# !Sample_characteristics_ch1                    rnum_full: R21868
# !Sample_characteristics_ch1                     sv1: -0.08201086
# !Sample_characteristics_ch1                    sv2: -0.022663835
# !Sample_characteristics_ch1                     sv3: 0.075913024
# !Sample_characteristics_ch1                     sv4: 0.026741706
# !Sample_characteristics_ch1                    sv5: -0.032939429
# !Sample_characteristics_ch1                     sv6: 0.006541241
# !Sample_characteristics_ch1                     sv7: 0.132937102
# !Sample_characteristics_ch1                    sv8: -0.056640236
# !Sample_characteristics_ch1                    sv9: -0.024693156
# !Sample_characteristics_ch1                   sv10: -0.018277265
# !Sample_characteristics_ch1                   sv11: -0.037882353
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.024693156
# !Sample_characteristics_ch1                   sv10: -0.018277265
# !Sample_characteristics_ch1                   sv11: -0.037882353
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21869  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015316
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 65.65377595
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 31
# !Sample_characteristics_ch1                     rin: 7.518326147
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: A12
# !Sample_characteristics_ch1                 brain number: Br8452
# !Sample_characteristics_ch1                    rnum_full: R21869
# !Sample_characteristics_ch1                    sv1: -0.145701549
# !Sample_characteristics_ch1                      sv2: 0.03907673
# !Sample_characteristics_ch1                    sv3: -0.022837658
# !Sample_characteristics_ch1                    sv4: -0.111374442
# !Sample_characteristics_ch1                     sv5: 0.057140103
# !Sample_characteristics_ch1                    sv6: -0.023021181
# !Sample_characteristics_ch1                     sv7: -0.10117231
# !Sample_characteristics_ch1                     sv8: 0.069894934
# !Sample_characteristics_ch1                     sv9: 0.022778735
# !Sample_characteristics_ch1                   sv10: -0.030566377
# !Sample_characteristics_ch1                    sv11: 0.028518952
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.022778735
# !Sample_characteristics_ch1                   sv10: -0.030566377
# !Sample_characteristics_ch1                    sv11: 0.028518952
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21870  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015317
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 78.03958476
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 35.5
# !Sample_characteristics_ch1                     rin: 7.999978633
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A12
# !Sample_characteristics_ch1                 brain number: Br8473
# !Sample_characteristics_ch1                    rnum_full: R21870
# !Sample_characteristics_ch1                     sv1: 0.096950112
# !Sample_characteristics_ch1                    sv2: -0.176953991
# !Sample_characteristics_ch1                     sv3: 0.024839524
# !Sample_characteristics_ch1                    sv4: -0.017511761
# !Sample_characteristics_ch1                    sv5: -0.067719259
# !Sample_characteristics_ch1                    sv6: -0.015596187
# !Sample_characteristics_ch1                    sv7: -0.015710538
# !Sample_characteristics_ch1                    sv8: -0.024241243
# !Sample_characteristics_ch1                     sv9: 0.084830078
# !Sample_characteristics_ch1                      sv10: -0.052159
# !Sample_characteristics_ch1                   sv11: -0.029571749
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.084830078
# !Sample_characteristics_ch1                      sv10: -0.052159
# !Sample_characteristics_ch1                   sv11: -0.029571749
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21871  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015318
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 48.02190281
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 30.5
# !Sample_characteristics_ch1                     rin: 6.975813733
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C03
# !Sample_characteristics_ch1                 brain number: Br8548
# !Sample_characteristics_ch1                    rnum_full: R21871
# !Sample_characteristics_ch1                      sv1: 0.24342652
# !Sample_characteristics_ch1                     sv2: 0.151936253
# !Sample_characteristics_ch1                     sv3: 0.087027904
# !Sample_characteristics_ch1                    sv4: -0.093655712
# !Sample_characteristics_ch1                     sv5: 0.008302872
# !Sample_characteristics_ch1                    sv6: -0.005632914
# !Sample_characteristics_ch1                     sv7: 0.009005214
# !Sample_characteristics_ch1                    sv8: -0.069637227
# !Sample_characteristics_ch1                    sv9: -0.149270255
# !Sample_characteristics_ch1                   sv10: -0.079711511
# !Sample_characteristics_ch1                      sv11: 0.0020547
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.149270255
# !Sample_characteristics_ch1                   sv10: -0.079711511
# !Sample_characteristics_ch1                      sv11: 0.0020547
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21872  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015319
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 57.62069359
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 32
# !Sample_characteristics_ch1                     rin: 6.791212389
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: G03
# !Sample_characteristics_ch1                 brain number: Br8569
# !Sample_characteristics_ch1                    rnum_full: R21872
# !Sample_characteristics_ch1                    sv1: -0.053787626
# !Sample_characteristics_ch1                    sv2: -0.016904082
# !Sample_characteristics_ch1                     sv3: 0.046033516
# !Sample_characteristics_ch1                     sv4: 0.005708063
# !Sample_characteristics_ch1                    sv5: -0.071841816
# !Sample_characteristics_ch1                    sv6: -0.041467184
# !Sample_characteristics_ch1                     sv7: 0.049986979
# !Sample_characteristics_ch1                     sv8: 0.023277504
# !Sample_characteristics_ch1                     sv9: 0.057672395
# !Sample_characteristics_ch1                     sv10: 0.05084497
# !Sample_characteristics_ch1                   sv11: -0.059813383
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.057672395
# !Sample_characteristics_ch1                     sv10: 0.05084497
# !Sample_characteristics_ch1                   sv11: -0.059813383
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21873  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015320
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 36.53661875
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 24
# !Sample_characteristics_ch1                     rin: 6.881841311
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B01
# !Sample_characteristics_ch1                 brain number: Br8660
# !Sample_characteristics_ch1                    rnum_full: R21873
# !Sample_characteristics_ch1                    sv1: -0.068088549
# !Sample_characteristics_ch1                     sv2: 0.018700691
# !Sample_characteristics_ch1                     sv3: 0.041840639
# !Sample_characteristics_ch1                     sv4: 0.026896275
# !Sample_characteristics_ch1                    sv5: -0.087751221
# !Sample_characteristics_ch1                    sv6: -0.052108151
# !Sample_characteristics_ch1                     sv7: 0.057891046
# !Sample_characteristics_ch1                     sv8: 0.003990728
# !Sample_characteristics_ch1                     sv9: -0.04395557
# !Sample_characteristics_ch1                   sv10: -0.069962646
# !Sample_characteristics_ch1                   sv11: -0.014912812
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: -0.04395557
# !Sample_characteristics_ch1                   sv10: -0.069962646
# !Sample_characteristics_ch1                   sv11: -0.014912812
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21874
# !Sample_title
# !Sample_geo_accession                                 GSM8015321
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 37.00205339
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 13
# !Sample_characteristics_ch1                     rin: 7.581523707
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B09
# !Sample_characteristics_ch1                 brain number: Br8663
# !Sample_characteristics_ch1                    rnum_full: R21874
# !Sample_characteristics_ch1                    sv1: -0.085046716
# !Sample_characteristics_ch1                     sv2: 0.044667521
# !Sample_characteristics_ch1                     sv3: 0.008215344
# !Sample_characteristics_ch1                    sv4: -0.031862978
# !Sample_characteristics_ch1                    sv5: -0.120639203
# !Sample_characteristics_ch1                    sv6: -0.159033516
# !Sample_characteristics_ch1                     sv7: 0.027614431
# !Sample_characteristics_ch1                    sv8: -0.004977403
# !Sample_characteristics_ch1                    sv9: -0.064843393
# !Sample_characteristics_ch1                    sv10: 0.002734964
# !Sample_characteristics_ch1                   sv11: -0.002558746
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.064843393
# !Sample_characteristics_ch1                    sv10: 0.002734964
# !Sample_characteristics_ch1                   sv11: -0.002558746
# !Sample_characteristics_ch1                             sv12: NA
#
# [30 rows x 194 columns]

# %% [markdown]
# # Look at AUD vs non-AUD

# %%
#grab specific row
audstatus = pd.Series(annot.iloc[3].values, index = list(annot.columns))
audstatus
# Out:
# R15181    dsm-5 aud status: non_AUD_Control
# R15183    dsm-5 aud status: non_AUD_Control
# R15207    dsm-5 aud status: non_AUD_Control
# R15274    dsm-5 aud status: non_AUD_Control
# R15394    dsm-5 aud status: non_AUD_Control
#                         ...
# R21870    dsm-5 aud status: non_AUD_Control
# R21871           dsm-5 aud status: AUD_Case
# R21872           dsm-5 aud status: AUD_Case
# R21873           dsm-5 aud status: AUD_Case
# R21874           dsm-5 aud status: AUD_Case
# Length: 194, dtype: object

# %%
#assign value based on control/case
colorsAUD = {'dsm-5 aud status: non_AUD_Control':0, 'dsm-5 aud status: AUD_Case':1}
cAUD=audstatus.map(colorsAUD)
cAUD
# Out:
# R15181    0
# R15183    0
# R15207    0
# R15274    0
# R15394    0
#          ..
# R21870    0
# R21871    1
# R21872    1
# R21873    1
# R21874    1
# Length: 194, dtype: int64

# %%
# make PCA
pcaAUD = PCA()
AUDcountsPCA = pcaAUD.fit_transform(transposecounts25pca)
variance_explained=pcaAUD.explained_variance_ratio_
pc1_variance=pcaAUD.explained_variance_ratio_[0]
pc2_variance=pcaAUD.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)
# Out:
# 13.999911784376822 5.714668752167194

# %%
AUDcountsPCA
# Out:
# array([[ 6.36841636e+00,  1.53113647e+01,  3.38612876e+01, ...,
#          4.41570215e+00,  5.04322266e+00,  1.51708763e-14],
#        [ 2.69517751e+01,  1.46395722e+01,  4.63226698e+01, ...,
#         -1.13956555e+01, -6.83292384e-01,  1.51708763e-14],
#        [ 3.91412872e+01, -1.13968134e+01, -4.62827258e+00, ...,
#         -2.74631706e-01, -4.77948670e+00,  1.51708763e-14],
#        ...,
#        [-4.34288990e+01, -1.05489478e+01, -5.59770945e+00, ...,
#          6.58888456e+00,  1.56294471e+00,  1.51708763e-14],
#        [-4.48124197e+01, -9.15537435e+00, -7.50597311e+00, ...,
#         -6.89257939e+00,  2.22239498e+00,  1.51708763e-14],
#        [-4.46013587e+01, -1.41664596e+01, -2.90571905e+00, ...,
#         -6.10761333e-01,  6.18264648e+00,  1.51708763e-14]])

# %%
#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=AUDcountsPCA[:, 0], y=AUDcountsPCA[:, 1], s=70, hue=audstatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()

# %% [markdown]
# # Look at Male vs Female

# %%
#grab specific row
gender = pd.Series(annot.iloc[4].values, index = list(annot.columns))
gender

#assign value based on control/case
colorsGender = {'Sex: M':0, 'Sex: F':1}
cGender=gender.map(colorsGender)
cGender

# make PCA
pcaGender = PCA()
GendercountsPCA = pcaGender.fit_transform(transposecounts25pca)
variance_explained=pcaGender.explained_variance_ratio_
pc1_variance=pcaGender.explained_variance_ratio_[0]
pc2_variance=pcaGender.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=GendercountsPCA[:, 0], y=GendercountsPCA[:, 1], s=70, hue=gender, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 13.999911784376822 5.714668752167194

# %% [markdown]
# # Look at Depressed vs Non-Depressed

# %%
#grab specific row
depressionStatus = pd.Series(annot.iloc[6].values, index = list(annot.columns))
depressionStatus

#assign value based on control/case
colorsDepressed = {'dsm-5 major depression diagnosis: 0':0, 'dsm-5 major depression diagnosis: 1':1}
cDepressed=gender.map(colorsDepressed)
cDepressed

# make PCA
pcaDepressed = PCA()
DepressedcountsPCA = pcaDepressed.fit_transform(transposecounts25pca)
variance_explained=pcaDepressed.explained_variance_ratio_
pc1_variance=pcaDepressed.explained_variance_ratio_[0]
pc2_variance=pcaDepressed.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=DepressedcountsPCA[:, 0], y=DepressedcountsPCA[:, 1], s=70, hue=depressionStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 13.999911784376822 5.714668752167194

# %% [markdown]
# # Look at Smoker vs Non-Smoker

# %%
#grab specific row
smokingStatus = pd.Series(annot.iloc[7].values, index = list(annot.columns))
smokingStatus

#assign value based on control/case
colorsSmoke = {'current smoker at death: Control':0, 'current smoker at death: Case':1}
cSmoke=gender.map(colorsSmoke)
cSmoke

# make PCA
pcaSmoke = PCA()
SmokecountsPCA = pcaSmoke.fit_transform(transposecounts25pca)
variance_explained=pcaSmoke.explained_variance_ratio_
pc1_variance=pcaSmoke.explained_variance_ratio_[0]
pc2_variance=pcaSmoke.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=SmokecountsPCA[:, 0], y=SmokecountsPCA[:, 1], s=70, hue=smokingStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 13.999911784376822 5.714668752167194

# %% [markdown]
# # Look at Brain Regions

# %%
#grab specific row
brainRegion = pd.Series(annot.iloc[1].values, index = list(annot.columns))
brainRegion

#assign value based on control/case
colorsBrain = {'Nucleus Accumbens':0, 'DLPFC':1}
cBrain=brainRegion.map(colorsBrain)
cBrain

# make PCA
pcaBrain = PCA()
BraincountsPCA = pcaBrain.fit_transform(transposecounts25pca)
variance_explained=pcaBrain.explained_variance_ratio_
pc1_variance=pcaBrain.explained_variance_ratio_[0]
pc2_variance=pcaBrain.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=BraincountsPCA[:, 0], y=BraincountsPCA[:, 1], s=70, hue=brainRegion, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 13.999911784376822 5.714668752167194

# %% [markdown]
# # Filter for PFC

# %%
# filter counts to only have samples in the NAc
bool_PFC = annot.iloc[1] == 'DLPFC'
counts = counts.drop('variance', axis = 1)
counts.columns = bool_PFC.index
counts_PFC = counts.loc[:,bool_PFC]

# %%
counts_PFC
# Out:
#                       R15899    R15908    R15915    R15973    R15977  \
# Gene
# ENSG00000259976.3   0.631940 -2.554381 -2.564994 -2.515617 -2.664163
# ENSG00000260075.1  -2.671256  0.244959  1.461131 -2.515617 -2.664163
# ENSG00000260186.5  -2.671256 -1.554381 -2.564994 -2.515617 -1.664163
# ENSG00000134184.13  0.974166 -1.253351  1.110785 -2.515617 -1.363133
# ENSG00000196273.8  -2.671256 -1.554381 -2.564994 -1.214587 -1.664163
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.778685  1.757372  1.679036  1.715343  1.733777
# ENSG00000204435.15  1.525749  1.473376  1.535377  1.495953  1.517966
# ENSG00000180304.14  1.808463  1.833720  1.822574  1.718140  1.839492
# ENSG00000111786.9   1.514569  1.541485  1.487700  1.456123  1.528683
# ENSG00000104824.18  1.938445  1.869847  1.955228  1.944980  1.964634
#
#                       R15981    R16002    R16078    R16099    R16102  ...  \
# Gene                                                                  ...
# ENSG00000259976.3  -2.352163  0.930524  1.009237  1.405648 -2.546907  ...
# ENSG00000260075.1   1.360486  1.060821 -2.354375  1.161054 -2.546907  ...
# ENSG00000260186.5  -2.352163 -1.715880 -1.053345 -1.438829 -2.546907  ...
# ENSG00000134184.13  1.007672 -1.715880 -1.053345  1.367351  0.964976  ...
# ENSG00000196273.8  -2.352163 -2.715880 -2.354375 -1.438829 -2.546907  ...
# ...                      ...       ...       ...       ...       ...  ...
# ENSG00000198218.11  1.796748  1.723453  1.750113  1.704498  1.734581  ...
# ENSG00000204435.15  1.542153  1.522417  1.516614  1.507623  1.506172  ...
# ENSG00000180304.14  1.800125  1.815344  1.782663  1.845827  1.841550  ...
# ENSG00000111786.9   1.530361  1.508653  1.507160  1.473924  1.499978  ...
# ENSG00000104824.18  1.970470  1.955848  1.909735  1.975643  1.945854  ...
#
#                       R21863    R21864    R21866    R21868    R21869  \
# Gene
# ENSG00000259976.3  -2.555105  0.649831 -2.650464 -2.714947  0.879852
# ENSG00000260075.1  -0.953045 -2.622010 -2.650464 -2.714947 -2.649065
# ENSG00000260186.5  -1.555105 -2.622010 -1.650464 -2.714947 -1.649065
# ENSG00000134184.13 -2.555105 -1.622010  1.078700  1.092588 -1.649065
# ENSG00000196273.8  -2.555105 -2.622010 -2.650464 -2.714947 -2.649065
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.744184  1.723167  1.720419  1.705174  1.732231
# ENSG00000204435.15  1.445329  1.508001  1.512995  1.486724  1.490184
# ENSG00000180304.14  1.744620  1.829162  1.846327  1.811134  1.837224
# ENSG00000111786.9   1.448786  1.487230  1.509103  1.490529  1.515288
# ENSG00000104824.18  1.905642  1.952368  1.911590  1.897943  1.909764
#
#                       R21870    R21871    R21872    R21873    R21874
# Gene
# ENSG00000259976.3  -2.377452 -2.574671 -2.563155 -2.685440  0.904112
# ENSG00000260075.1  -2.377452  0.901000 -0.058005 -2.685440 -2.738353
# ENSG00000260186.5  -2.377452 -1.273641 -1.086034 -2.685440 -2.738353
# ENSG00000134184.13  1.018748  1.107474 -2.563155  1.285371  1.132636
# ENSG00000196273.8  -2.377452 -2.574671 -2.563155 -2.685440 -2.738353
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.745419  1.671827  1.764408  1.737478  1.688484
# ENSG00000204435.15  1.525638  1.490535  1.478632  1.504331  1.466038
# ENSG00000180304.14  1.792223  1.815910  1.820840  1.838046  1.831840
# ENSG00000111786.9   1.456333  1.469476  1.467040  1.512942  1.524335
# ENSG00000104824.18  1.885237  1.923777  1.901185  1.904956  1.907757
#
# [42163 rows x 96 columns]

# %%
# filter annot for only NAc
annot_PFC = annot.loc[:, bool_PFC]

# %%
annot_PFC
# Out:
#                                                           R15899  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015226
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                       agedeath: 52.5
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 25
# !Sample_characteristics_ch1                              rin: 10
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: A08
# !Sample_characteristics_ch1                 brain number: Br5060
# !Sample_characteristics_ch1                    rnum_full: R15899
# !Sample_characteristics_ch1                     sv1: 0.076253458
# !Sample_characteristics_ch1                     sv2: 0.070000645
# !Sample_characteristics_ch1                    sv3: -0.089045231
# !Sample_characteristics_ch1                     sv4: -0.13824572
# !Sample_characteristics_ch1                    sv5: -0.229711127
# !Sample_characteristics_ch1                     sv6: 0.377919454
# !Sample_characteristics_ch1                    sv7: -0.122686084
# !Sample_characteristics_ch1                     sv8: 0.078181318
# !Sample_characteristics_ch1                    sv9: -0.145421014
# !Sample_characteristics_ch1                     sv10: 0.12527323
# !Sample_characteristics_ch1                   sv11: -0.158428304
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.145421014
# !Sample_characteristics_ch1                     sv10: 0.12527323
# !Sample_characteristics_ch1                   sv11: -0.158428304
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R15908  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015227
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                       agedeath: 54.2
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 40
# !Sample_characteristics_ch1                             rin: 8.9
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: A03
# !Sample_characteristics_ch1                 brain number: Br5163
# !Sample_characteristics_ch1                    rnum_full: R15908
# !Sample_characteristics_ch1                    sv1: -0.008097168
# !Sample_characteristics_ch1                    sv2: -0.084340265
# !Sample_characteristics_ch1                     sv3: 0.123677122
# !Sample_characteristics_ch1                      sv4: 0.03793301
# !Sample_characteristics_ch1                     sv5: 0.085050043
# !Sample_characteristics_ch1                     sv6: 0.077582448
# !Sample_characteristics_ch1                    sv7: -0.050442266
# !Sample_characteristics_ch1                     sv8: -0.07953705
# !Sample_characteristics_ch1                     sv9: 0.058606915
# !Sample_characteristics_ch1                    sv10: 0.110725303
# !Sample_characteristics_ch1                     sv11: 0.06098711
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.058606915
# !Sample_characteristics_ch1                    sv10: 0.110725303
# !Sample_characteristics_ch1                     sv11: 0.06098711
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R15915  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015228
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                       agedeath: 56.7
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 25.5
# !Sample_characteristics_ch1                             rin: 8.8
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: H04
# !Sample_characteristics_ch1                 brain number: Br5211
# !Sample_characteristics_ch1             rnum_full: R15915_merged
# !Sample_characteristics_ch1                     sv1: 0.073794249
# !Sample_characteristics_ch1                     sv2: -0.15068731
# !Sample_characteristics_ch1                     sv3: 0.021815387
# !Sample_characteristics_ch1                    sv4: -0.043690308
# !Sample_characteristics_ch1                    sv5: -0.034399042
# !Sample_characteristics_ch1                    sv6: -0.010029884
# !Sample_characteristics_ch1                    sv7: -0.045329856
# !Sample_characteristics_ch1                    sv8: -0.085616228
# !Sample_characteristics_ch1                     sv9: 0.137290943
# !Sample_characteristics_ch1                    sv10: 0.112008339
# !Sample_characteristics_ch1                   sv11: -0.115959515
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.137290943
# !Sample_characteristics_ch1                    sv10: 0.112008339
# !Sample_characteristics_ch1                   sv11: -0.115959515
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R15973  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015229
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 61.75
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 22.5
# !Sample_characteristics_ch1                             rin: 8.2
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: B04
# !Sample_characteristics_ch1                 brain number: Br5262
# !Sample_characteristics_ch1                  rnum_full: R15973_1
# !Sample_characteristics_ch1                    sv1: -0.008366007
# !Sample_characteristics_ch1                    sv2: -0.015877903
# !Sample_characteristics_ch1                     sv3: 0.078430848
# !Sample_characteristics_ch1                    sv4: -0.060403682
# !Sample_characteristics_ch1                     sv5: 0.118515601
# !Sample_characteristics_ch1                     sv6: 0.074302033
# !Sample_characteristics_ch1                     sv7: 0.020004686
# !Sample_characteristics_ch1                      sv8: 0.06940017
# !Sample_characteristics_ch1                     sv9: 0.205330713
# !Sample_characteristics_ch1                    sv10: 0.020859138
# !Sample_characteristics_ch1                   sv11: -0.089524139
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.205330713
# !Sample_characteristics_ch1                    sv10: 0.020859138
# !Sample_characteristics_ch1                   sv11: -0.089524139
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R15977  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015230
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 48.69
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 41.5
# !Sample_characteristics_ch1                             rin: 8.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: F09
# !Sample_characteristics_ch1                 brain number: Br5314
# !Sample_characteristics_ch1                    rnum_full: R15977
# !Sample_characteristics_ch1                     sv1: 0.142141855
# !Sample_characteristics_ch1                     sv2: 0.159989557
# !Sample_characteristics_ch1                     sv3: -0.04782953
# !Sample_characteristics_ch1                     sv4: 0.208452775
# !Sample_characteristics_ch1                    sv5: -0.051669981
# !Sample_characteristics_ch1                    sv6: -0.111279629
# !Sample_characteristics_ch1                    sv7: -0.089039511
# !Sample_characteristics_ch1                    sv8: -0.078653054
# !Sample_characteristics_ch1                    sv9: -0.013553699
# !Sample_characteristics_ch1                   sv10: -0.069810887
# !Sample_characteristics_ch1                    sv11: 0.023342618
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.013553699
# !Sample_characteristics_ch1                   sv10: -0.069810887
# !Sample_characteristics_ch1                    sv11: 0.023342618
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R15981  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015231
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 76.69
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 28.5
# !Sample_characteristics_ch1                             rin: 7.8
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: E12
# !Sample_characteristics_ch1                 brain number: Br5293
# !Sample_characteristics_ch1                    rnum_full: R15981
# !Sample_characteristics_ch1                     sv1: 0.023739919
# !Sample_characteristics_ch1                    sv2: -0.020779394
# !Sample_characteristics_ch1                     sv3: 0.060988581
# !Sample_characteristics_ch1                    sv4: -0.094004073
# !Sample_characteristics_ch1                     sv5: 0.161532787
# !Sample_characteristics_ch1                     sv6: 0.093892893
# !Sample_characteristics_ch1                     sv7: -0.13351834
# !Sample_characteristics_ch1                     sv8: 0.041583339
# !Sample_characteristics_ch1                    sv9: -0.117653877
# !Sample_characteristics_ch1                   sv10: -0.074606163
# !Sample_characteristics_ch1                    sv11: 0.014425664
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.117653877
# !Sample_characteristics_ch1                   sv10: -0.074606163
# !Sample_characteristics_ch1                    sv11: 0.014425664
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R16002  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015232
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 43.11
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 16
# !Sample_characteristics_ch1                             rin: 8.4
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A03
# !Sample_characteristics_ch1                 brain number: Br5829
# !Sample_characteristics_ch1                    rnum_full: R16002
# !Sample_characteristics_ch1                    sv1: -0.023531913
# !Sample_characteristics_ch1                     sv2: 0.041634181
# !Sample_characteristics_ch1                     sv3: 0.046376194
# !Sample_characteristics_ch1                     sv4: 0.018860116
# !Sample_characteristics_ch1                    sv5: -0.095541896
# !Sample_characteristics_ch1                    sv6: -0.061146646
# !Sample_characteristics_ch1                    sv7: -0.035016203
# !Sample_characteristics_ch1                    sv8: -0.028763091
# !Sample_characteristics_ch1                    sv9: -0.080717811
# !Sample_characteristics_ch1                   sv10: -0.094362272
# !Sample_characteristics_ch1                   sv11: -0.021676344
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.080717811
# !Sample_characteristics_ch1                   sv10: -0.094362272
# !Sample_characteristics_ch1                   sv11: -0.021676344
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R16078  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015233
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 59.86
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 26
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: F03
# !Sample_characteristics_ch1                 brain number: Br5276
# !Sample_characteristics_ch1                    rnum_full: R16078
# !Sample_characteristics_ch1                     sv1: 0.090008888
# !Sample_characteristics_ch1                    sv2: -0.218551795
# !Sample_characteristics_ch1                    sv3: -0.031184856
# !Sample_characteristics_ch1                    sv4: -0.052964832
# !Sample_characteristics_ch1                     sv5: -0.13246708
# !Sample_characteristics_ch1                    sv6: -0.006185362
# !Sample_characteristics_ch1                     sv7: -0.02481437
# !Sample_characteristics_ch1                     sv8: 0.089677624
# !Sample_characteristics_ch1                    sv9: -0.115358405
# !Sample_characteristics_ch1                    sv10: 0.212754514
# !Sample_characteristics_ch1                    sv11: -0.07219064
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.115358405
# !Sample_characteristics_ch1                    sv10: 0.212754514
# !Sample_characteristics_ch1                    sv11: -0.07219064
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R16099  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015234
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 52.69
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 23.5
# !Sample_characteristics_ch1                             rin: 6.9
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: E11
# !Sample_characteristics_ch1                 brain number: Br5400
# !Sample_characteristics_ch1                    rnum_full: R16099
# !Sample_characteristics_ch1                     sv1: 0.226102711
# !Sample_characteristics_ch1                     sv2: 0.197433954
# !Sample_characteristics_ch1                     sv3: -0.04319045
# !Sample_characteristics_ch1                     sv4: 0.083916888
# !Sample_characteristics_ch1                     sv5: 0.091294367
# !Sample_characteristics_ch1                    sv6: -0.005349364
# !Sample_characteristics_ch1                     sv7: 0.078861824
# !Sample_characteristics_ch1                     sv8: 0.112344301
# !Sample_characteristics_ch1                    sv9: -0.186859183
# !Sample_characteristics_ch1                    sv10: 0.043525599
# !Sample_characteristics_ch1                    sv11: 0.044339367
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.186859183
# !Sample_characteristics_ch1                    sv10: 0.043525599
# !Sample_characteristics_ch1                    sv11: 0.044339367
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R16102  ...  \
# !Sample_title                                                     ...
# !Sample_geo_accession                                 GSM8015235  ...
# !Sample_source_name_ch1                                    DLPFC  ...
# !Sample_characteristics_ch1                        tissue: DLPFC  ...
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control  ...
# !Sample_characteristics_ch1                               Sex: M  ...
# !Sample_characteristics_ch1                      agedeath: 38.99  ...
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0  ...
# !Sample_characteristics_ch1        current smoker at death: Case  ...
# !Sample_characteristics_ch1                              pmi: 32  ...
# !Sample_characteristics_ch1                             rin: 7.7  ...
# !Sample_characteristics_ch1                      sample plate: 2  ...
# !Sample_characteristics_ch1                     sample well: F01  ...
# !Sample_characteristics_ch1                 brain number: Br5459  ...
# !Sample_characteristics_ch1                    rnum_full: R16102  ...
# !Sample_characteristics_ch1                    sv1: -0.021090296  ...
# !Sample_characteristics_ch1                    sv2: -0.045772119  ...
# !Sample_characteristics_ch1                     sv3: 0.096363254  ...
# !Sample_characteristics_ch1                      sv4: 0.01914643  ...
# !Sample_characteristics_ch1                     sv5: 0.053943132  ...
# !Sample_characteristics_ch1                     sv6: 0.022692114  ...
# !Sample_characteristics_ch1                     sv7: -0.01855737  ...
# !Sample_characteristics_ch1                     sv8: 0.093601489  ...
# !Sample_characteristics_ch1                    sv9: -0.098014658  ...
# !Sample_characteristics_ch1                    sv10: 0.049231368  ...
# !Sample_characteristics_ch1                       sv11: 0.116595  ...
# !Sample_characteristics_ch1                             sv12: NA  ...
# !Sample_characteristics_ch1                    sv9: -0.098014658  ...
# !Sample_characteristics_ch1                    sv10: 0.049231368  ...
# !Sample_characteristics_ch1                       sv11: 0.116595  ...
# !Sample_characteristics_ch1                             sv12: NA  ...
#
#                                                           R21863  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015312
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 37.42379649
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 33
# !Sample_characteristics_ch1                     rin: 7.497769295
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: B05
# !Sample_characteristics_ch1                 brain number: Br3925
# !Sample_characteristics_ch1                  rnum_full: R21863_1
# !Sample_characteristics_ch1                    sv1: -0.107503745
# !Sample_characteristics_ch1                     sv2: 0.089097193
# !Sample_characteristics_ch1                     sv3: 0.068016747
# !Sample_characteristics_ch1                     sv4: 0.022182646
# !Sample_characteristics_ch1                     sv5: 0.013130758
# !Sample_characteristics_ch1                     sv6: 0.095584713
# !Sample_characteristics_ch1                     sv7: 0.017436871
# !Sample_characteristics_ch1                     sv8: 0.058732866
# !Sample_characteristics_ch1                     sv9: 0.184997306
# !Sample_characteristics_ch1                   sv10: -0.185306802
# !Sample_characteristics_ch1                   sv11: -0.125824471
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.184997306
# !Sample_characteristics_ch1                   sv10: -0.185306802
# !Sample_characteristics_ch1                   sv11: -0.125824471
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21864  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015313
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 44.77481177
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 23.5
# !Sample_characteristics_ch1                       rin: 7.6541342
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: F05
# !Sample_characteristics_ch1                 brain number: Br3953
# !Sample_characteristics_ch1                    rnum_full: R21864
# !Sample_characteristics_ch1                    sv1: -0.110342856
# !Sample_characteristics_ch1                     sv2: 0.006809833
# !Sample_characteristics_ch1                    sv3: -0.127752187
# !Sample_characteristics_ch1                    sv4: -0.082172681
# !Sample_characteristics_ch1                    sv5: -0.200186512
# !Sample_characteristics_ch1                     sv6: 0.016950482
# !Sample_characteristics_ch1                    sv7: -0.150901672
# !Sample_characteristics_ch1                    sv8: -0.072879542
# !Sample_characteristics_ch1                     sv9: 0.014725284
# !Sample_characteristics_ch1                   sv10: -0.003110154
# !Sample_characteristics_ch1                   sv11: -0.146179861
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.014725284
# !Sample_characteristics_ch1                   sv10: -0.003110154
# !Sample_characteristics_ch1                   sv11: -0.146179861
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21866  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015314
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 64.26009582
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 22
# !Sample_characteristics_ch1                     rin: 7.512599528
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: D01
# !Sample_characteristics_ch1                 brain number: Br6393
# !Sample_characteristics_ch1                    rnum_full: R21866
# !Sample_characteristics_ch1                     sv1: 0.012575385
# !Sample_characteristics_ch1                    sv2: -0.001294275
# !Sample_characteristics_ch1                     sv3: 0.064167682
# !Sample_characteristics_ch1                    sv4: -0.009037275
# !Sample_characteristics_ch1                    sv5: -0.003742677
# !Sample_characteristics_ch1                     sv6: 0.033805367
# !Sample_characteristics_ch1                     sv7: -0.04244638
# !Sample_characteristics_ch1                     sv8: 0.055603272
# !Sample_characteristics_ch1                    sv9: -0.022571642
# !Sample_characteristics_ch1                   sv10: -0.021176236
# !Sample_characteristics_ch1                   sv11: -0.005320233
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.022571642
# !Sample_characteristics_ch1                   sv10: -0.021176236
# !Sample_characteristics_ch1                   sv11: -0.005320233
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21868  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015315
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 57.05692448
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 37.5
# !Sample_characteristics_ch1                     rin: 7.140684806
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A02
# !Sample_characteristics_ch1                 brain number: Br8408
# !Sample_characteristics_ch1                    rnum_full: R21868
# !Sample_characteristics_ch1                     sv1: -0.08201086
# !Sample_characteristics_ch1                    sv2: -0.022663835
# !Sample_characteristics_ch1                     sv3: 0.075913024
# !Sample_characteristics_ch1                     sv4: 0.026741706
# !Sample_characteristics_ch1                    sv5: -0.032939429
# !Sample_characteristics_ch1                     sv6: 0.006541241
# !Sample_characteristics_ch1                     sv7: 0.132937102
# !Sample_characteristics_ch1                    sv8: -0.056640236
# !Sample_characteristics_ch1                    sv9: -0.024693156
# !Sample_characteristics_ch1                   sv10: -0.018277265
# !Sample_characteristics_ch1                   sv11: -0.037882353
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.024693156
# !Sample_characteristics_ch1                   sv10: -0.018277265
# !Sample_characteristics_ch1                   sv11: -0.037882353
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21869  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015316
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 65.65377595
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 31
# !Sample_characteristics_ch1                     rin: 7.518326147
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: A12
# !Sample_characteristics_ch1                 brain number: Br8452
# !Sample_characteristics_ch1                    rnum_full: R21869
# !Sample_characteristics_ch1                    sv1: -0.145701549
# !Sample_characteristics_ch1                      sv2: 0.03907673
# !Sample_characteristics_ch1                    sv3: -0.022837658
# !Sample_characteristics_ch1                    sv4: -0.111374442
# !Sample_characteristics_ch1                     sv5: 0.057140103
# !Sample_characteristics_ch1                    sv6: -0.023021181
# !Sample_characteristics_ch1                     sv7: -0.10117231
# !Sample_characteristics_ch1                     sv8: 0.069894934
# !Sample_characteristics_ch1                     sv9: 0.022778735
# !Sample_characteristics_ch1                   sv10: -0.030566377
# !Sample_characteristics_ch1                    sv11: 0.028518952
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.022778735
# !Sample_characteristics_ch1                   sv10: -0.030566377
# !Sample_characteristics_ch1                    sv11: 0.028518952
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21870  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015317
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 78.03958476
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 35.5
# !Sample_characteristics_ch1                     rin: 7.999978633
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A12
# !Sample_characteristics_ch1                 brain number: Br8473
# !Sample_characteristics_ch1                    rnum_full: R21870
# !Sample_characteristics_ch1                     sv1: 0.096950112
# !Sample_characteristics_ch1                    sv2: -0.176953991
# !Sample_characteristics_ch1                     sv3: 0.024839524
# !Sample_characteristics_ch1                    sv4: -0.017511761
# !Sample_characteristics_ch1                    sv5: -0.067719259
# !Sample_characteristics_ch1                    sv6: -0.015596187
# !Sample_characteristics_ch1                    sv7: -0.015710538
# !Sample_characteristics_ch1                    sv8: -0.024241243
# !Sample_characteristics_ch1                     sv9: 0.084830078
# !Sample_characteristics_ch1                      sv10: -0.052159
# !Sample_characteristics_ch1                   sv11: -0.029571749
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.084830078
# !Sample_characteristics_ch1                      sv10: -0.052159
# !Sample_characteristics_ch1                   sv11: -0.029571749
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21871  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015318
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 48.02190281
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 30.5
# !Sample_characteristics_ch1                     rin: 6.975813733
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C03
# !Sample_characteristics_ch1                 brain number: Br8548
# !Sample_characteristics_ch1                    rnum_full: R21871
# !Sample_characteristics_ch1                      sv1: 0.24342652
# !Sample_characteristics_ch1                     sv2: 0.151936253
# !Sample_characteristics_ch1                     sv3: 0.087027904
# !Sample_characteristics_ch1                    sv4: -0.093655712
# !Sample_characteristics_ch1                     sv5: 0.008302872
# !Sample_characteristics_ch1                    sv6: -0.005632914
# !Sample_characteristics_ch1                     sv7: 0.009005214
# !Sample_characteristics_ch1                    sv8: -0.069637227
# !Sample_characteristics_ch1                    sv9: -0.149270255
# !Sample_characteristics_ch1                   sv10: -0.079711511
# !Sample_characteristics_ch1                      sv11: 0.0020547
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.149270255
# !Sample_characteristics_ch1                   sv10: -0.079711511
# !Sample_characteristics_ch1                      sv11: 0.0020547
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21872  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015319
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 57.62069359
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 32
# !Sample_characteristics_ch1                     rin: 6.791212389
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: G03
# !Sample_characteristics_ch1                 brain number: Br8569
# !Sample_characteristics_ch1                    rnum_full: R21872
# !Sample_characteristics_ch1                    sv1: -0.053787626
# !Sample_characteristics_ch1                    sv2: -0.016904082
# !Sample_characteristics_ch1                     sv3: 0.046033516
# !Sample_characteristics_ch1                     sv4: 0.005708063
# !Sample_characteristics_ch1                    sv5: -0.071841816
# !Sample_characteristics_ch1                    sv6: -0.041467184
# !Sample_characteristics_ch1                     sv7: 0.049986979
# !Sample_characteristics_ch1                     sv8: 0.023277504
# !Sample_characteristics_ch1                     sv9: 0.057672395
# !Sample_characteristics_ch1                     sv10: 0.05084497
# !Sample_characteristics_ch1                   sv11: -0.059813383
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: 0.057672395
# !Sample_characteristics_ch1                     sv10: 0.05084497
# !Sample_characteristics_ch1                   sv11: -0.059813383
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21873  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015320
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 36.53661875
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 24
# !Sample_characteristics_ch1                     rin: 6.881841311
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B01
# !Sample_characteristics_ch1                 brain number: Br8660
# !Sample_characteristics_ch1                    rnum_full: R21873
# !Sample_characteristics_ch1                    sv1: -0.068088549
# !Sample_characteristics_ch1                     sv2: 0.018700691
# !Sample_characteristics_ch1                     sv3: 0.041840639
# !Sample_characteristics_ch1                     sv4: 0.026896275
# !Sample_characteristics_ch1                    sv5: -0.087751221
# !Sample_characteristics_ch1                    sv6: -0.052108151
# !Sample_characteristics_ch1                     sv7: 0.057891046
# !Sample_characteristics_ch1                     sv8: 0.003990728
# !Sample_characteristics_ch1                     sv9: -0.04395557
# !Sample_characteristics_ch1                   sv10: -0.069962646
# !Sample_characteristics_ch1                   sv11: -0.014912812
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                     sv9: -0.04395557
# !Sample_characteristics_ch1                   sv10: -0.069962646
# !Sample_characteristics_ch1                   sv11: -0.014912812
# !Sample_characteristics_ch1                             sv12: NA
#
#                                                           R21874
# !Sample_title
# !Sample_geo_accession                                 GSM8015321
# !Sample_source_name_ch1                                    DLPFC
# !Sample_characteristics_ch1                        tissue: DLPFC
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 37.00205339
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 13
# !Sample_characteristics_ch1                     rin: 7.581523707
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B09
# !Sample_characteristics_ch1                 brain number: Br8663
# !Sample_characteristics_ch1                    rnum_full: R21874
# !Sample_characteristics_ch1                    sv1: -0.085046716
# !Sample_characteristics_ch1                     sv2: 0.044667521
# !Sample_characteristics_ch1                     sv3: 0.008215344
# !Sample_characteristics_ch1                    sv4: -0.031862978
# !Sample_characteristics_ch1                    sv5: -0.120639203
# !Sample_characteristics_ch1                    sv6: -0.159033516
# !Sample_characteristics_ch1                     sv7: 0.027614431
# !Sample_characteristics_ch1                    sv8: -0.004977403
# !Sample_characteristics_ch1                    sv9: -0.064843393
# !Sample_characteristics_ch1                    sv10: 0.002734964
# !Sample_characteristics_ch1                   sv11: -0.002558746
# !Sample_characteristics_ch1                             sv12: NA
# !Sample_characteristics_ch1                    sv9: -0.064843393
# !Sample_characteristics_ch1                    sv10: 0.002734964
# !Sample_characteristics_ch1                   sv11: -0.002558746
# !Sample_characteristics_ch1                             sv12: NA
#
# [30 rows x 96 columns]

# %%
# calculate variance again
#calculate variance for each row and add as new column
counts_PFC['variance'] = counts.var(axis=1)

#sort by variance
counts_PFC.sort_values(by='variance', ascending=False, inplace=True)
counts_PFC

#take top 4748 (approx 25%) of highest variance
counts25pca_PFC = counts_PFC.head(4748)

#delete variance column
counts25pca_PFC = counts25pca_PFC.drop('variance', axis = 1)
# Out:
# /tmp/ipykernel_3766735/1460457901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_PFC['variance'] = counts.var(axis=1)
# /tmp/ipykernel_3766735/1460457901.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_PFC.sort_values(by='variance', ascending=False, inplace=True)

# %%
#transpose selected counts data
transposecounts25pca_PFC = counts25pca_PFC.T.values
transposecounts25pca_PFC = preprocessing.StandardScaler().fit_transform(transposecounts25pca_PFC)

# %% [markdown]
# ## AUD vs Non AUD

# %%
#grab specific row
audstatus = pd.Series(annot_PFC.iloc[3].values, index = list(annot_PFC.columns))
audstatus

#assign value based on control/case
colorsAUD = {'dsm-5 aud status: non_AUD_Control':0, 'dsm-5 aud status: AUD_Case':1}
cAUD=audstatus.map(colorsAUD)
cAUD

# make PCA
pcaAUD = PCA()
AUDcountsPCA = pcaAUD.fit_transform(transposecounts25pca_PFC)
variance_explained=pcaAUD.explained_variance_ratio_
pc1_variance=pcaAUD.explained_variance_ratio_[0]
pc2_variance=pcaAUD.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=AUDcountsPCA[:, 0], y=AUDcountsPCA[:, 1], s=70, hue=audstatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 7.829549485816657 4.3240880605367735

# %% [markdown]
# ## Male vs Female

# %%
#grab specific row
gender = pd.Series(annot_PFC.iloc[4].values, index = list(annot_PFC.columns))
gender

#assign value based on control/case
colorsGender = {'Sex: M':0, 'Sex: F':1}
cGender=gender.map(colorsGender)
cGender

# make PCA
pcaGender = PCA()
GendercountsPCA = pcaGender.fit_transform(transposecounts25pca_PFC)
variance_explained=pcaGender.explained_variance_ratio_
pc1_variance=pcaGender.explained_variance_ratio_[0]
pc2_variance=pcaGender.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=GendercountsPCA[:, 0], y=GendercountsPCA[:, 1], s=70, hue=gender, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 7.829549485816657 4.3240880605367735

# %% [markdown]
# ## Depressed vs Not Depressed

# %%
#grab specific row
depressionStatus = pd.Series(annot_PFC.iloc[6].values, index = list(annot_PFC.columns))
depressionStatus

#assign value based on control/case
colorsDepressed = {'dsm-5 major depression diagnosis: 0':0, 'dsm-5 major depression diagnosis: 1':1}
cDepressed=gender.map(colorsDepressed)
cDepressed

# make PCA
pcaDepressed = PCA()
DepressedcountsPCA = pcaDepressed.fit_transform(transposecounts25pca_PFC)
variance_explained=pcaDepressed.explained_variance_ratio_
pc1_variance=pcaDepressed.explained_variance_ratio_[0]
pc2_variance=pcaDepressed.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=DepressedcountsPCA[:, 0], y=DepressedcountsPCA[:, 1], s=70, hue=depressionStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 7.829549485816657 4.3240880605367735

# %% [markdown]
# ## Smoke vs No Smoke

# %%
#grab specific row
smokingStatus = pd.Series(annot_PFC.iloc[7].values, index = list(annot_PFC.columns))
smokingStatus

#assign value based on control/case
colorsSmoke = {'current smoker at death: Control':0, 'current smoker at death: Case':1}
cSmoke=gender.map(colorsSmoke)
cSmoke

# make PCA
pcaSmoke = PCA()
SmokecountsPCA = pcaSmoke.fit_transform(transposecounts25pca_PFC)
variance_explained=pcaSmoke.explained_variance_ratio_
pc1_variance=pcaSmoke.explained_variance_ratio_[0]
pc2_variance=pcaSmoke.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=SmokecountsPCA[:, 0], y=SmokecountsPCA[:, 1], s=70, hue=smokingStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 7.829549485816657 4.3240880605367735

# %% [markdown]
# ## Age Death

# %%
# Grab the 'agedeath' values
age = pd.Series(annot_PFC.iloc[5].values, index=list(annot_PFC.columns))

# Clean them
age_clean = age.apply(lambda x: float(x.split(':')[1].strip()))

# Do PCA
pcaAge = PCA()
AgecountsPCA = pcaAge.fit_transform(transposecounts25pca_PFC)

variance_explained = pcaAge.explained_variance_ratio_
pc1_variance = variance_explained[0]
pc2_variance = variance_explained[1]

# Scatterplot
sns.scatterplot(x=AgecountsPCA[:, 0], y=AgecountsPCA[:, 1], hue=age_clean, palette='coolwarm')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()

# %% [markdown]
# ## Look at whether sv1-sv12 are affecting the PCA

# %%
# This finds all row indexes where 'sv1:' appears in any cell
sv1_rows = annot.index[
    annot.applymap(str).apply(lambda row: row.apply(lambda x: 'sv1:' in x)).any(axis=1)
]

print(sv1_rows)
# Out:
# Index(['!Sample_characteristics_ch1'], dtype='object', name='!Sample_title')
# /tmp/ipykernel_4069296/3560482264.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   annot.applymap(str).apply(lambda row: row.apply(lambda x: 'sv1:' in x)).any(axis=1)

# %%
# Assume idx_sv1 is the correct index you found
sv1_row = annot.iloc[14].astype(str)

# Extract the float values
SV1 = sv1_row.apply(lambda x: float(x.split(':')[1].strip()))

# %%
# Extract the float values for sv1
SV1 = sv1_row.apply(lambda x: float(x.split('sv1:')[1].split(';')[0].strip()))

# %%
plt.scatter(SV1, GendercountsPCA[:, 0])
plt.xlabel('SV1')
plt.ylabel('PC1')
plt.title('SV1 vs PC1')
plt.show()

# %% [markdown]
# # Filter for NAc

# %%
# filter counts to only have samples in the NAc
bool_NAc = annot.iloc[1] == 'Nucleus Accumbens'
#counts = counts.drop('variance', axis = 1)
counts.columns = bool_NAc.index
counts_NAc = counts.loc[:,bool_NAc]

# %%
counts_NAc
# Out:
#                       R15181    R15183    R15207    R15274    R15394  \
# Gene
# ENSG00000259976.3  -2.519063 -2.558822  1.065913  0.788256 -2.603460
# ENSG00000260075.1   1.244365 -2.558822 -2.406844 -2.700295 -2.603460
# ENSG00000260186.5   0.093720  0.436813  0.931613  0.785427  1.042944
# ENSG00000134184.13  1.209290 -2.558822 -2.406844 -1.700295 -2.603460
# ENSG00000196273.8   0.300480  0.131374  0.826152  0.746863  0.632069
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.641705  1.615238  1.625372  1.747948  1.653979
# ENSG00000204435.15  1.417953  1.502631  1.419231  1.514019  1.491011
# ENSG00000180304.14  1.646478  1.800064  1.731143  1.781148  1.783396
# ENSG00000111786.9   1.415435  1.485326  1.425665  1.501649  1.463239
# ENSG00000104824.18  1.860967  1.932680  1.908497  1.925121  1.877983
#
#                       R15395    R15396    R15399    R15402    R15428  ...  \
# Gene                                                                  ...
# ENSG00000259976.3  -2.671445 -2.639801  1.027146  0.906429 -2.495750  ...
# ENSG00000260075.1   1.412058 -2.639801  1.592462  1.223812  1.125426  ...
# ENSG00000260186.5   1.191283  1.050396  0.978503  1.208972  1.123343  ...
# ENSG00000134184.13  1.668801  1.236994 -1.452861  1.269472 -1.495750  ...
# ENSG00000196273.8   0.652838  0.791563  0.869359  0.769890  0.644129  ...
# ...                      ...       ...       ...       ...       ...  ...
# ENSG00000198218.11  1.677250  1.673645  1.739428  1.698984  1.676268  ...
# ENSG00000204435.15  1.518046  1.514623  1.516089  1.479787  1.461857  ...
# ENSG00000180304.14  1.804081  1.801266  1.811957  1.765582  1.782546  ...
# ENSG00000111786.9   1.499989  1.506017  1.481132  1.479787  1.418593  ...
# ENSG00000104824.18  1.886543  1.904143  1.950431  1.916315  1.860849  ...
#
#                       R21951    R21952    R21954    R21955    R21956  \
# Gene
# ENSG00000259976.3  -2.589211  0.753827  1.313131  1.143211  1.332759
# ENSG00000260075.1  -2.589211  0.566356 -2.722299  1.025696 -1.124618
# ENSG00000260186.5   1.232957  0.761251  1.031284  0.489530  0.851579
# ENSG00000134184.13  1.556297  1.175091 -1.245178 -2.523307  1.423567
# ENSG00000196273.8   0.772517  0.926578  0.937617  0.764495  0.763749
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.731973  1.752828  1.729180  1.706375  1.682240
# ENSG00000204435.15  1.448614  1.518458  1.546747  1.500768  1.508177
# ENSG00000180304.14  1.788642  1.842879  1.827807  1.834247  1.821998
# ENSG00000111786.9   1.447019  1.536942  1.488554  1.481874  1.441230
# ENSG00000104824.18  1.895089  1.952453  1.928106  1.927558  1.932921
#
#                       R21958    R21959    R21960    R21961    R21962
# Gene
# ENSG00000259976.3  -2.297293 -2.393157 -2.566943  0.790930  1.272954
# ENSG00000260075.1  -2.297293 -2.393157 -2.566943 -2.627372 -2.596864
# ENSG00000260186.5   0.194069  0.445692  0.961974  0.509349  0.881702
# ENSG00000134184.13 -0.255900 -1.393157  1.173420 -1.025312  1.016978
# ENSG00000196273.8   0.374805  0.451941  0.861192  0.649090  0.783347
# ...                      ...       ...       ...       ...       ...
# ENSG00000198218.11  1.679057  1.691419  1.703503  1.742215  1.749489
# ENSG00000204435.15  1.547185  1.421090  1.414876  1.557320  1.504195
# ENSG00000180304.14  1.814642  1.814477  1.723981  1.801411  1.832242
# ENSG00000111786.9   1.431061  1.496144  1.434358  1.457562  1.488783
# ENSG00000104824.18  1.891636  1.947485  1.908583  1.942821  1.919142
#
# [42163 rows x 98 columns]

# %%
# filter annot for only NAc
annot_NAc = annot.loc[:, bool_NAc]

# %%
annot_NAc
# Out:
#                                                           R15181  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015128
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 31.54
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 25
# !Sample_characteristics_ch1                             rin: 8.3
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: D05
# !Sample_characteristics_ch1                 brain number: Br1735
# !Sample_characteristics_ch1                    rnum_full: R15181
# !Sample_characteristics_ch1                    sv1: -0.229646051
# !Sample_characteristics_ch1                      sv2: 0.13859236
# !Sample_characteristics_ch1                      sv3: 0.07841074
# !Sample_characteristics_ch1                     sv4: 0.206190077
# !Sample_characteristics_ch1                      sv5: 0.03510265
# !Sample_characteristics_ch1                    sv6: -0.054085138
# !Sample_characteristics_ch1                     sv7: 0.192960398
# !Sample_characteristics_ch1                    sv8: -0.027965902
# !Sample_characteristics_ch1                     sv9: 0.173312723
# !Sample_characteristics_ch1                   sv10: -0.011115271
# !Sample_characteristics_ch1                    sv11: 0.064231982
# !Sample_characteristics_ch1                   sv12: -0.255029407
# !Sample_characteristics_ch1                     sv9: 0.173312723
# !Sample_characteristics_ch1                   sv10: -0.011115271
# !Sample_characteristics_ch1                    sv11: 0.064231982
# !Sample_characteristics_ch1                   sv12: -0.255029407
#
#                                                           R15183  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015129
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 35.25
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 16
# !Sample_characteristics_ch1                             rin: 7.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: H06
# !Sample_characteristics_ch1                 brain number: Br1995
# !Sample_characteristics_ch1             rnum_full: R15183_merged
# !Sample_characteristics_ch1                    sv1: -0.278660251
# !Sample_characteristics_ch1                     sv2: 0.216070294
# !Sample_characteristics_ch1                     sv3: 0.035467512
# !Sample_characteristics_ch1                    sv4: -0.057936977
# !Sample_characteristics_ch1                     sv5: 0.033479646
# !Sample_characteristics_ch1                     sv6: 0.040689475
# !Sample_characteristics_ch1                    sv7: -0.003116882
# !Sample_characteristics_ch1                     sv8: 0.168936507
# !Sample_characteristics_ch1                     sv9: 0.086255745
# !Sample_characteristics_ch1                    sv10: 0.065034378
# !Sample_characteristics_ch1                   sv11: -0.024624171
# !Sample_characteristics_ch1                    sv12: 0.042397304
# !Sample_characteristics_ch1                     sv9: 0.086255745
# !Sample_characteristics_ch1                    sv10: 0.065034378
# !Sample_characteristics_ch1                   sv11: -0.024624171
# !Sample_characteristics_ch1                    sv12: 0.042397304
#
#                                                           R15207  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015130
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 61.75
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 22.5
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: E07
# !Sample_characteristics_ch1                 brain number: Br5262
# !Sample_characteristics_ch1                    rnum_full: R15207
# !Sample_characteristics_ch1                     sv1: 0.008438168
# !Sample_characteristics_ch1                    sv2: -0.021005976
# !Sample_characteristics_ch1                     sv3: 0.025962544
# !Sample_characteristics_ch1                     sv4: -0.04310767
# !Sample_characteristics_ch1                     sv5: 0.120178949
# !Sample_characteristics_ch1                    sv6: -0.135392533
# !Sample_characteristics_ch1                     sv7: 0.106729625
# !Sample_characteristics_ch1                    sv8: -0.016302217
# !Sample_characteristics_ch1                     sv9: 0.248518998
# !Sample_characteristics_ch1                    sv10: 0.008790364
# !Sample_characteristics_ch1                    sv11: 0.022981964
# !Sample_characteristics_ch1                   sv12: -0.016178927
# !Sample_characteristics_ch1                     sv9: 0.248518998
# !Sample_characteristics_ch1                    sv10: 0.008790364
# !Sample_characteristics_ch1                    sv11: 0.022981964
# !Sample_characteristics_ch1                   sv12: -0.016178927
#
#                                                           R15274  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015131
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 38.39
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 41
# !Sample_characteristics_ch1                               rin: 8
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: A10
# !Sample_characteristics_ch1                 brain number: Br1474
# !Sample_characteristics_ch1                    rnum_full: R15274
# !Sample_characteristics_ch1                     sv1: 0.044189388
# !Sample_characteristics_ch1                     sv2: 0.088108542
# !Sample_characteristics_ch1                    sv3: -0.017637236
# !Sample_characteristics_ch1                    sv4: -0.083645152
# !Sample_characteristics_ch1                    sv5: -0.178076113
# !Sample_characteristics_ch1                     sv6: 0.001464592
# !Sample_characteristics_ch1                     sv7: 0.188789719
# !Sample_characteristics_ch1                     sv8: 0.053503479
# !Sample_characteristics_ch1                    sv9: -0.005126922
# !Sample_characteristics_ch1                    sv10: 0.089448624
# !Sample_characteristics_ch1                    sv11: 0.210044746
# !Sample_characteristics_ch1                    sv12: 0.026841514
# !Sample_characteristics_ch1                    sv9: -0.005126922
# !Sample_characteristics_ch1                    sv10: 0.089448624
# !Sample_characteristics_ch1                    sv11: 0.210044746
# !Sample_characteristics_ch1                    sv12: 0.026841514
#
#                                                           R15394  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015132
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 46.79
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 21
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C07
# !Sample_characteristics_ch1                 brain number: Br2638
# !Sample_characteristics_ch1                    rnum_full: R15394
# !Sample_characteristics_ch1                      sv1: 0.06504724
# !Sample_characteristics_ch1                     sv2: 0.103257252
# !Sample_characteristics_ch1                    sv3: -0.007719585
# !Sample_characteristics_ch1                    sv4: -0.109417427
# !Sample_characteristics_ch1                     sv5: 0.140067633
# !Sample_characteristics_ch1                    sv6: -0.076831227
# !Sample_characteristics_ch1                     sv7: 0.191481655
# !Sample_characteristics_ch1                    sv8: -0.100146364
# !Sample_characteristics_ch1                     sv9: 0.033382681
# !Sample_characteristics_ch1                    sv10: 0.253915529
# !Sample_characteristics_ch1                   sv11: -0.036598844
# !Sample_characteristics_ch1                    sv12: 0.070337294
# !Sample_characteristics_ch1                     sv9: 0.033382681
# !Sample_characteristics_ch1                    sv10: 0.253915529
# !Sample_characteristics_ch1                   sv11: -0.036598844
# !Sample_characteristics_ch1                    sv12: 0.070337294
#
#                                                           R15395  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015133
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                      agedeath: 52.69
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 23.5
# !Sample_characteristics_ch1                             rin: 7.7
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: C01
# !Sample_characteristics_ch1                 brain number: Br5400
# !Sample_characteristics_ch1                    rnum_full: R15395
# !Sample_characteristics_ch1                     sv1: 0.068777173
# !Sample_characteristics_ch1                     sv2: 0.107345992
# !Sample_characteristics_ch1                      sv3: 0.06285047
# !Sample_characteristics_ch1                    sv4: -0.103439046
# !Sample_characteristics_ch1                    sv5: -0.109903519
# !Sample_characteristics_ch1                    sv6: -0.143630473
# !Sample_characteristics_ch1                     sv7: 0.200374278
# !Sample_characteristics_ch1                    sv8: -0.031331634
# !Sample_characteristics_ch1                     sv9: 0.001002766
# !Sample_characteristics_ch1                    sv10: 0.058719835
# !Sample_characteristics_ch1                    sv11: 0.094183124
# !Sample_characteristics_ch1                    sv12: 0.026086442
# !Sample_characteristics_ch1                     sv9: 0.001002766
# !Sample_characteristics_ch1                    sv10: 0.058719835
# !Sample_characteristics_ch1                    sv11: 0.094183124
# !Sample_characteristics_ch1                    sv12: 0.026086442
#
#                                                           R15396  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015134
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 38.99
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 32
# !Sample_characteristics_ch1                             rin: 7.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: C09
# !Sample_characteristics_ch1                 brain number: Br5459
# !Sample_characteristics_ch1                    rnum_full: R15396
# !Sample_characteristics_ch1                     sv1: 0.046323532
# !Sample_characteristics_ch1                     sv2: 0.000643698
# !Sample_characteristics_ch1                     sv3: 0.015659769
# !Sample_characteristics_ch1                    sv4: -0.007792991
# !Sample_characteristics_ch1                     sv5: 0.088717041
# !Sample_characteristics_ch1                    sv6: -0.058996178
# !Sample_characteristics_ch1                     sv7: 0.168468041
# !Sample_characteristics_ch1                     sv8: 0.206292703
# !Sample_characteristics_ch1                    sv9: -0.051335434
# !Sample_characteristics_ch1                    sv10: 0.019317293
# !Sample_characteristics_ch1                    sv11: 0.074310413
# !Sample_characteristics_ch1                    sv12: 0.025425311
# !Sample_characteristics_ch1                    sv9: -0.051335434
# !Sample_characteristics_ch1                    sv10: 0.019317293
# !Sample_characteristics_ch1                    sv11: 0.074310413
# !Sample_characteristics_ch1                    sv12: 0.025425311
#
#                                                           R15399  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015135
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 65.59057723
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 27
# !Sample_characteristics_ch1                             rin: 6.5
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B10
# !Sample_characteristics_ch1                 brain number: Br5864
# !Sample_characteristics_ch1                    rnum_full: R15399
# !Sample_characteristics_ch1                    sv1: -0.176622553
# !Sample_characteristics_ch1                    sv2: -0.258413183
# !Sample_characteristics_ch1                    sv3: -0.211797828
# !Sample_characteristics_ch1                    sv4: -0.114486883
# !Sample_characteristics_ch1                     sv5: 0.142546871
# !Sample_characteristics_ch1                    sv6: -0.138818262
# !Sample_characteristics_ch1                     sv7: 0.055849332
# !Sample_characteristics_ch1                    sv8: -0.059027088
# !Sample_characteristics_ch1                    sv9: -0.208278414
# !Sample_characteristics_ch1                   sv10: -0.001963668
# !Sample_characteristics_ch1                    sv11: 0.034595176
# !Sample_characteristics_ch1                   sv12: -0.069664972
# !Sample_characteristics_ch1                    sv9: -0.208278414
# !Sample_characteristics_ch1                   sv10: -0.001963668
# !Sample_characteristics_ch1                    sv11: 0.034595176
# !Sample_characteristics_ch1                   sv12: -0.069664972
#
#                                                           R15402  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015136
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                      agedeath: 52.92
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 28
# !Sample_characteristics_ch1                             rin: 7.6
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: E06
# !Sample_characteristics_ch1                 brain number: Br5368
# !Sample_characteristics_ch1                    rnum_full: R15402
# !Sample_characteristics_ch1                     sv1: 0.073570839
# !Sample_characteristics_ch1                     sv2: 0.069655361
# !Sample_characteristics_ch1                     sv3: 0.092511005
# !Sample_characteristics_ch1                    sv4: -0.064893341
# !Sample_characteristics_ch1                     sv5: 0.115461612
# !Sample_characteristics_ch1                    sv6: -0.024157891
# !Sample_characteristics_ch1                     sv7: 0.116666182
# !Sample_characteristics_ch1                     sv8: 0.015519259
# !Sample_characteristics_ch1                    sv9: -0.133853998
# !Sample_characteristics_ch1                    sv10: 0.107523381
# !Sample_characteristics_ch1                     sv11: 0.01286849
# !Sample_characteristics_ch1                    sv12: 0.100814481
# !Sample_characteristics_ch1                    sv9: -0.133853998
# !Sample_characteristics_ch1                    sv10: 0.107523381
# !Sample_characteristics_ch1                     sv11: 0.01286849
# !Sample_characteristics_ch1                    sv12: 0.100814481
#
#                                                           R15428  ...  \
# !Sample_title                                                     ...
# !Sample_geo_accession                                 GSM8015137  ...
# !Sample_source_name_ch1                        Nucleus Accumbens  ...
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens  ...
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control  ...
# !Sample_characteristics_ch1                               Sex: M  ...
# !Sample_characteristics_ch1                      agedeath: 43.11  ...
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0  ...
# !Sample_characteristics_ch1     current smoker at death: Control  ...
# !Sample_characteristics_ch1                              pmi: 16  ...
# !Sample_characteristics_ch1                               rin: 7  ...
# !Sample_characteristics_ch1                      sample plate: 1  ...
# !Sample_characteristics_ch1                     sample well: C04  ...
# !Sample_characteristics_ch1                 brain number: Br5829  ...
# !Sample_characteristics_ch1                    rnum_full: R15428  ...
# !Sample_characteristics_ch1                    sv1: -0.016555083  ...
# !Sample_characteristics_ch1                    sv2: -0.013719968  ...
# !Sample_characteristics_ch1                     sv3: 0.177913849  ...
# !Sample_characteristics_ch1                    sv4: -0.073783129  ...
# !Sample_characteristics_ch1                     sv5: 0.107973092  ...
# !Sample_characteristics_ch1                    sv6: -0.015207092  ...
# !Sample_characteristics_ch1                     sv7: 0.102996227  ...
# !Sample_characteristics_ch1                     sv8: 0.004263393  ...
# !Sample_characteristics_ch1                    sv9: -0.187991496  ...
# !Sample_characteristics_ch1                    sv10: 0.180577707  ...
# !Sample_characteristics_ch1                   sv11: -0.067369302  ...
# !Sample_characteristics_ch1                    sv12: 0.034761337  ...
# !Sample_characteristics_ch1                    sv9: -0.187991496  ...
# !Sample_characteristics_ch1                    sv10: 0.180577707  ...
# !Sample_characteristics_ch1                   sv11: -0.067369302  ...
# !Sample_characteristics_ch1                    sv12: 0.034761337  ...
#
#                                                           R21951  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015216
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 62.07802875
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 24
# !Sample_characteristics_ch1                             rin: 7.3
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: H11
# !Sample_characteristics_ch1                 brain number: Br8137
# !Sample_characteristics_ch1             rnum_full: R21951_merged
# !Sample_characteristics_ch1                     sv1: 0.082170789
# !Sample_characteristics_ch1                    sv2: -0.060769061
# !Sample_characteristics_ch1                      sv3: 0.03945833
# !Sample_characteristics_ch1                    sv4: -0.019555282
# !Sample_characteristics_ch1                     sv5: 0.107856455
# !Sample_characteristics_ch1                     sv6: 0.051216609
# !Sample_characteristics_ch1                     sv7: 0.118800629
# !Sample_characteristics_ch1                     sv8: 0.015509235
# !Sample_characteristics_ch1                    sv9: -0.100503222
# !Sample_characteristics_ch1                   sv10: -0.075741783
# !Sample_characteristics_ch1                     sv11: 0.01914263
# !Sample_characteristics_ch1                    sv12: 0.077590583
# !Sample_characteristics_ch1                    sv9: -0.100503222
# !Sample_characteristics_ch1                   sv10: -0.075741783
# !Sample_characteristics_ch1                     sv11: 0.01914263
# !Sample_characteristics_ch1                    sv12: 0.077590583
#
#                                                           R21952  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015217
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                 agedeath: 47.8110883
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 26.5
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: F11
# !Sample_characteristics_ch1                 brain number: Br8140
# !Sample_characteristics_ch1                    rnum_full: R21952
# !Sample_characteristics_ch1                    sv1: -0.015685003
# !Sample_characteristics_ch1                    sv2: -0.066460384
# !Sample_characteristics_ch1                    sv3: -0.114694644
# !Sample_characteristics_ch1                     sv4: 0.122552122
# !Sample_characteristics_ch1                     sv5: 0.024272221
# !Sample_characteristics_ch1                    sv6: -0.049269766
# !Sample_characteristics_ch1                     sv7: 0.039773136
# !Sample_characteristics_ch1                     sv8: 0.005288187
# !Sample_characteristics_ch1                    sv9: -0.018090643
# !Sample_characteristics_ch1                     sv10: 0.00410092
# !Sample_characteristics_ch1                    sv11: 0.094100495
# !Sample_characteristics_ch1                   sv12: -0.058744936
# !Sample_characteristics_ch1                    sv9: -0.018090643
# !Sample_characteristics_ch1                     sv10: 0.00410092
# !Sample_characteristics_ch1                    sv11: 0.094100495
# !Sample_characteristics_ch1                   sv12: -0.058744936
#
#                                                           R21954  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015218
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 49.41010723
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                              pmi: 20
# !Sample_characteristics_ch1                             rin: 7.6
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: B07
# !Sample_characteristics_ch1                 brain number: Br8252
# !Sample_characteristics_ch1                    rnum_full: R21954
# !Sample_characteristics_ch1                     sv1: 0.093710528
# !Sample_characteristics_ch1                    sv2: -0.099882614
# !Sample_characteristics_ch1                    sv3: -0.026178724
# !Sample_characteristics_ch1                     sv4: 0.001636331
# !Sample_characteristics_ch1                     sv5: 0.030471539
# !Sample_characteristics_ch1                     sv6: 0.075785536
# !Sample_characteristics_ch1                    sv7: -0.084412388
# !Sample_characteristics_ch1                     sv8: 0.110692983
# !Sample_characteristics_ch1                    sv9: -0.102984333
# !Sample_characteristics_ch1                    sv10: 0.039644973
# !Sample_characteristics_ch1                    sv11: 0.064817719
# !Sample_characteristics_ch1                    sv12: 0.085831352
# !Sample_characteristics_ch1                    sv9: -0.102984333
# !Sample_characteristics_ch1                    sv10: 0.039644973
# !Sample_characteristics_ch1                    sv11: 0.064817719
# !Sample_characteristics_ch1                    sv12: 0.085831352
#
#                                                           R21955  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015219
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                agedeath: 29.12251882
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 18.5
# !Sample_characteristics_ch1                             rin: 7.8
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: C12
# !Sample_characteristics_ch1                 brain number: Br8262
# !Sample_characteristics_ch1                    rnum_full: R21955
# !Sample_characteristics_ch1                    sv1: -0.042642604
# !Sample_characteristics_ch1                      sv2: 0.01634978
# !Sample_characteristics_ch1                    sv3: -0.256569083
# !Sample_characteristics_ch1                     sv4: 0.000838627
# !Sample_characteristics_ch1                    sv5: -0.172566486
# !Sample_characteristics_ch1                    sv6: -0.106513164
# !Sample_characteristics_ch1                    sv7: -0.007573958
# !Sample_characteristics_ch1                      sv8: 0.01254403
# !Sample_characteristics_ch1                    sv9: -0.221507342
# !Sample_characteristics_ch1                   sv10: -0.113542492
# !Sample_characteristics_ch1                    sv11: 0.044982679
# !Sample_characteristics_ch1                   sv12: -0.017551791
# !Sample_characteristics_ch1                    sv9: -0.221507342
# !Sample_characteristics_ch1                   sv10: -0.113542492
# !Sample_characteristics_ch1                    sv11: 0.044982679
# !Sample_characteristics_ch1                   sv12: -0.017551791
#
#                                                           R21956  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015220
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 73.63449692
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 21.5
# !Sample_characteristics_ch1                             rin: 7.7
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: H08
# !Sample_characteristics_ch1                 brain number: Br8290
# !Sample_characteristics_ch1             rnum_full: R21956_merged
# !Sample_characteristics_ch1                     sv1: 0.024028739
# !Sample_characteristics_ch1                     sv2: 0.080421489
# !Sample_characteristics_ch1                    sv3: -0.065736896
# !Sample_characteristics_ch1                     sv4: 0.013667453
# !Sample_characteristics_ch1                    sv5: -0.000874017
# !Sample_characteristics_ch1                     sv6: 0.057797463
# !Sample_characteristics_ch1                    sv7: -0.128838034
# !Sample_characteristics_ch1                     sv8: 0.024376552
# !Sample_characteristics_ch1                     sv9: 0.165247505
# !Sample_characteristics_ch1                    sv10: 0.068178781
# !Sample_characteristics_ch1                    sv11: 0.039186941
# !Sample_characteristics_ch1                    sv12: 0.119984764
# !Sample_characteristics_ch1                     sv9: 0.165247505
# !Sample_characteristics_ch1                    sv10: 0.068178781
# !Sample_characteristics_ch1                    sv11: 0.039186941
# !Sample_characteristics_ch1                    sv12: 0.119984764
#
#                                                           R21958  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015221
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 55.41672371
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 13.5
# !Sample_characteristics_ch1                             rin: 5.6
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: G06
# !Sample_characteristics_ch1                 brain number: Br8313
# !Sample_characteristics_ch1                    rnum_full: R21958
# !Sample_characteristics_ch1                    sv1: -0.260514527
# !Sample_characteristics_ch1                     sv2: 0.072410069
# !Sample_characteristics_ch1                    sv3: -0.182777633
# !Sample_characteristics_ch1                    sv4: -0.124931127
# !Sample_characteristics_ch1                     sv5: 0.056179288
# !Sample_characteristics_ch1                     sv6: 0.005655258
# !Sample_characteristics_ch1                     sv7: 0.088272208
# !Sample_characteristics_ch1                     sv8: 0.191333186
# !Sample_characteristics_ch1                    sv9: -0.002491803
# !Sample_characteristics_ch1                   sv10: -0.124381356
# !Sample_characteristics_ch1                   sv11: -0.193883889
# !Sample_characteristics_ch1                    sv12: 0.170539312
# !Sample_characteristics_ch1                    sv9: -0.002491803
# !Sample_characteristics_ch1                   sv10: -0.124381356
# !Sample_characteristics_ch1                   sv11: -0.193883889
# !Sample_characteristics_ch1                    sv12: 0.170539312
#
#                                                           R21959  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015222
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 78.37907826
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 36
# !Sample_characteristics_ch1                             rin: 7.4
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: E05
# !Sample_characteristics_ch1                 brain number: Br8338
# !Sample_characteristics_ch1                    rnum_full: R21959
# !Sample_characteristics_ch1                    sv1: -0.096731002
# !Sample_characteristics_ch1                     sv2: 0.096159082
# !Sample_characteristics_ch1                    sv3: -0.069092686
# !Sample_characteristics_ch1                     sv4: 0.081050931
# !Sample_characteristics_ch1                    sv5: -0.021851161
# !Sample_characteristics_ch1                     sv6: 0.021426603
# !Sample_characteristics_ch1                    sv7: -0.135810449
# !Sample_characteristics_ch1                     sv8: 0.040567903
# !Sample_characteristics_ch1                     sv9: 0.272821881
# !Sample_characteristics_ch1                    sv10: 0.024991748
# !Sample_characteristics_ch1                   sv11: -0.019465505
# !Sample_characteristics_ch1                    sv12: 0.102763908
# !Sample_characteristics_ch1                     sv9: 0.272821881
# !Sample_characteristics_ch1                    sv10: 0.024991748
# !Sample_characteristics_ch1                   sv11: -0.019465505
# !Sample_characteristics_ch1                    sv12: 0.102763908
#
#                                                           R21960  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015223
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: M
# !Sample_characteristics_ch1                agedeath: 47.28542094
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                              pmi: 23
# !Sample_characteristics_ch1                             rin: 7.9
# !Sample_characteristics_ch1                      sample plate: 3
# !Sample_characteristics_ch1                     sample well: E01
# !Sample_characteristics_ch1                 brain number: Br8357
# !Sample_characteristics_ch1                    rnum_full: R21960
# !Sample_characteristics_ch1                     sv1: 0.102792984
# !Sample_characteristics_ch1                    sv2: -0.065791958
# !Sample_characteristics_ch1                    sv3: -0.022804935
# !Sample_characteristics_ch1                     sv4: 0.061741719
# !Sample_characteristics_ch1                     sv5: 0.075530077
# !Sample_characteristics_ch1                    sv6: -0.023733253
# !Sample_characteristics_ch1                     sv7: 0.078182409
# !Sample_characteristics_ch1                    sv8: -0.018687379
# !Sample_characteristics_ch1                     sv9: 0.088340477
# !Sample_characteristics_ch1                   sv10: -0.243011653
# !Sample_characteristics_ch1                    sv11: 0.043104409
# !Sample_characteristics_ch1                   sv12: -0.143539347
# !Sample_characteristics_ch1                     sv9: 0.088340477
# !Sample_characteristics_ch1                   sv10: -0.243011653
# !Sample_characteristics_ch1                    sv11: 0.043104409
# !Sample_characteristics_ch1                   sv12: -0.143539347
#
#                                                           R21961  \
# !Sample_title
# !Sample_geo_accession                                 GSM8015224
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1    dsm-5 aud status: non_AUD_Control
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                agedeath: 24.76374629
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 1
# !Sample_characteristics_ch1     current smoker at death: Control
# !Sample_characteristics_ch1                            pmi: 26.5
# !Sample_characteristics_ch1                               rin: 8
# !Sample_characteristics_ch1                      sample plate: 1
# !Sample_characteristics_ch1                     sample well: D08
# !Sample_characteristics_ch1                 brain number: Br8382
# !Sample_characteristics_ch1             rnum_full: R21961_merged
# !Sample_characteristics_ch1                     sv1: 0.001134221
# !Sample_characteristics_ch1                     sv2: 0.057666589
# !Sample_characteristics_ch1                    sv3: -0.031512319
# !Sample_characteristics_ch1                      sv4: 0.04027968
# !Sample_characteristics_ch1                    sv5: -0.213406468
# !Sample_characteristics_ch1                    sv6: -0.035264129
# !Sample_characteristics_ch1                    sv7: -0.001329737
# !Sample_characteristics_ch1                      sv8: 0.11226894
# !Sample_characteristics_ch1                     sv9: -0.04149626
# !Sample_characteristics_ch1                   sv10: -0.102535813
# !Sample_characteristics_ch1                   sv11: -0.004476525
# !Sample_characteristics_ch1                    sv12: 0.037994204
# !Sample_characteristics_ch1                     sv9: -0.04149626
# !Sample_characteristics_ch1                   sv10: -0.102535813
# !Sample_characteristics_ch1                   sv11: -0.004476525
# !Sample_characteristics_ch1                    sv12: 0.037994204
#
#                                                           R21962
# !Sample_title
# !Sample_geo_accession                                 GSM8015225
# !Sample_source_name_ch1                        Nucleus Accumbens
# !Sample_characteristics_ch1            tissue: Nucleus Accumbens
# !Sample_characteristics_ch1           dsm-5 aud status: AUD_Case
# !Sample_characteristics_ch1                               Sex: F
# !Sample_characteristics_ch1                 agedeath: 37.4701118
# !Sample_characteristics_ch1  dsm-5 major depression diagnosis: 0
# !Sample_characteristics_ch1        current smoker at death: Case
# !Sample_characteristics_ch1                            pmi: 17.5
# !Sample_characteristics_ch1                             rin: 8.2
# !Sample_characteristics_ch1                      sample plate: 2
# !Sample_characteristics_ch1                     sample well: F02
# !Sample_characteristics_ch1                 brain number: Br8392
# !Sample_characteristics_ch1                    rnum_full: R21962
# !Sample_characteristics_ch1                     sv1: 0.079730461
# !Sample_characteristics_ch1                     sv2: 0.047482139
# !Sample_characteristics_ch1                     sv3: 0.010408552
# !Sample_characteristics_ch1                     sv4: 0.050640446
# !Sample_characteristics_ch1                    sv5: -0.211128294
# !Sample_characteristics_ch1                    sv6: -0.056231961
# !Sample_characteristics_ch1                    sv7: -0.041964682
# !Sample_characteristics_ch1                    sv8: -0.005858471
# !Sample_characteristics_ch1                    sv9: -0.005844694
# !Sample_characteristics_ch1                   sv10: -0.003651879
# !Sample_characteristics_ch1                   sv11: -0.040720467
# !Sample_characteristics_ch1                    sv12: 0.051976718
# !Sample_characteristics_ch1                    sv9: -0.005844694
# !Sample_characteristics_ch1                   sv10: -0.003651879
# !Sample_characteristics_ch1                   sv11: -0.040720467
# !Sample_characteristics_ch1                    sv12: 0.051976718
#
# [30 rows x 98 columns]

# %%
# calculate variance again
#calculate variance for each row and add as new column
counts_NAc['variance'] = counts.var(axis=1)

#sort by variance
counts_NAc.sort_values(by='variance', ascending=False, inplace=True)
counts_NAc

#take top 4748 (approx 25%) of highest variance
counts25pca_NAc = counts_NAc.head(4748)

#delete variance column
counts25pca_NAc = counts25pca_NAc.drop('variance', axis = 1)
# Out:
# /tmp/ipykernel_3766735/3060476004.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_NAc['variance'] = counts.var(axis=1)
# /tmp/ipykernel_3766735/3060476004.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   counts_NAc.sort_values(by='variance', ascending=False, inplace=True)

# %%
#transpose selected counts data
transposecounts25pca_NAc = counts25pca_NAc.T.values
transposecounts25pca_NAc = preprocessing.StandardScaler().fit_transform(transposecounts25pca_NAc)
transposecounts25pca_NAc
# Out:
# array([[-1.27993625,  0.9799237 , -2.92654437, ...,  0.98761437,
#         -0.0793746 , -1.53113495],
#        [-1.30242691, -1.1074365 , -1.66302037, ...,  0.45593922,
#          0.60655962,  0.45643705],
#        [ 0.74801866, -1.02402404,  0.15920069, ...,  1.78353094,
#         -1.47171751, -1.35429386],
#        ...,
#        [-1.30702088, -1.11189375,  0.2710123 , ..., -1.11686313,
#         -1.72280788, -1.60658597],
#        [ 0.59246578, -1.14505973, -1.39589024, ..., -1.21113987,
#         -0.24923903,  0.62590602],
#        [ 0.86513816, -1.12831578, -0.02460652, ..., -1.16354398,
#         -0.2013927 , -0.07788917]])

# %% [markdown]
# ## AUD vs Non AUD

# %%
#grab specific row
audstatus = pd.Series(annot_NAc.iloc[3].values, index = list(annot_NAc.columns))
audstatus

#assign value based on control/case
colorsAUD = {'dsm-5 aud status: non_AUD_Control':0, 'dsm-5 aud status: AUD_Case':1}
cAUD=audstatus.map(colorsAUD)
cAUD

# make PCA
pcaAUD = PCA()
AUDcountsPCA = pcaAUD.fit_transform(transposecounts25pca_NAc)
variance_explained=pcaAUD.explained_variance_ratio_
pc1_variance=pcaAUD.explained_variance_ratio_[0]
pc2_variance=pcaAUD.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=AUDcountsPCA[:, 0], y=AUDcountsPCA[:, 1], s=70, hue=audstatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 8.024366530187505 5.486763910146642

# %% [markdown]
# ## Male vs Female

# %%
#grab specific row
gender = pd.Series(annot_NAc.iloc[4].values, index = list(annot_NAc.columns))
gender

#assign value based on control/case
colorsGender = {'Sex: M':0, 'Sex: F':1}
cGender=gender.map(colorsGender)
cGender

# make PCA
pcaGender = PCA()
GendercountsPCA = pcaGender.fit_transform(transposecounts25pca_NAc)
variance_explained=pcaGender.explained_variance_ratio_
pc1_variance=pcaGender.explained_variance_ratio_[0]
pc2_variance=pcaGender.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=GendercountsPCA[:, 0], y=GendercountsPCA[:, 1], s=70, hue=gender, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 8.024366530187505 5.486763910146642

# %% [markdown]
# ## Depressed vs Not Depressed

# %%
#grab specific row
depressionStatus = pd.Series(annot_NAc.iloc[6].values, index = list(annot_NAc.columns))
depressionStatus

#assign value based on control/case
colorsDepressed = {'dsm-5 major depression diagnosis: 0':0, 'dsm-5 major depression diagnosis: 1':1}
cDepressed=gender.map(colorsDepressed)
cDepressed

# make PCA
pcaDepressed = PCA()
DepressedcountsPCA = pcaDepressed.fit_transform(transposecounts25pca_NAc)
variance_explained=pcaDepressed.explained_variance_ratio_
pc1_variance=pcaDepressed.explained_variance_ratio_[0]
pc2_variance=pcaDepressed.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=DepressedcountsPCA[:, 0], y=DepressedcountsPCA[:, 1], s=70, hue=depressionStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 8.024366530187505 5.486763910146642

# %% [markdown]
# ## Smoke vs No Smoke

# %%
#grab specific row
smokingStatus = pd.Series(annot_NAc.iloc[7].values, index = list(annot_NAc.columns))
smokingStatus

#assign value based on control/case
colorsSmoke = {'current smoker at death: Control':0, 'current smoker at death: Case':1}
cSmoke=gender.map(colorsSmoke)
cSmoke

# make PCA
pcaSmoke = PCA()
SmokecountsPCA = pcaSmoke.fit_transform(transposecounts25pca_NAc)
variance_explained=pcaSmoke.explained_variance_ratio_
pc1_variance=pcaSmoke.explained_variance_ratio_[0]
pc2_variance=pcaSmoke.explained_variance_ratio_[1]

print(pc1_variance*100,pc2_variance*100)

#scatter=plt.scatter(x_new[:,0], x_new[:,1],c=c)
sns.scatterplot(x=SmokecountsPCA[:, 0], y=SmokecountsPCA[:, 1], s=70, hue=smokingStatus, palette=['red', 'green'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
# Out:
# 8.024366530187505 5.486763910146642

# %% [markdown]
# ## Age Death

# %%
# Grab the 'agedeath' values
age = pd.Series(annot_NAc.iloc[5].values, index=list(annot_NAc.columns))

# Clean them
age_clean = age.apply(lambda x: float(x.split(':')[1].strip()))

# Do PCA
pcaAge = PCA()
AgecountsPCA = pcaAge.fit_transform(transposecounts25pca_NAc)

variance_explained = pcaAge.explained_variance_ratio_
pc1_variance = variance_explained[0]
pc2_variance = variance_explained[1]

# Scatterplot
sns.scatterplot(x=AgecountsPCA[:, 0], y=AgecountsPCA[:, 1], hue=age_clean, palette='coolwarm')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title("PCA scatterplot: " + str(round(pc1_variance*100,2)) + "% variance explained", pad=15)
plt.show()
