# %%
import math 
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn

# %%
annotationsFile = "series matrix.csv"
annotations= pd.read_csv(
    annotationsFile,
    sep = ",",
    header =0, 
    index_col =0,
)

annotations
# Out:
#                                                                               R15181  \
# !Sample_title
# !Sample_geo_accession                                                     GSM8015128
# !dsm-5 aud status                                  dsm-5 aud status: non_AUD_Control
# !Sex                                                                          Sex: M
# !agedeath                                                            agedeath: 31.54
# !dsm-5 major depression diagnosis                dsm-5 major depression diagnosis: 0
# !current smoker at death                               current smoker at death: Case
# !pmi                                                                         pmi: 25
# !rin                                                                        rin: 8.3
# !sample plate                                                        sample plate: 3
# !sample well                                                        sample well: D05
# ...

# %%
annotations.loc["!rnum_full"]
# Out:
# R15181           rnum_full: R15181
# R15183    rnum_full: R15183_merged
# R15207           rnum_full: R15207
# R15274           rnum_full: R15274
# R15394           rnum_full: R15394
#                     ...
# R21870           rnum_full: R21870
# R21871           rnum_full: R21871
# R21872           rnum_full: R21872
# R21873           rnum_full: R21873
# R21874           rnum_full: R21874
# Name: !rnum_full, Length: 194, dtype: object

# %%
countsFile = "counts.csv"
counts= pd.read_csv(
    countsFile,
    sep = ",",
    header =0, 
    index_col =0,
)
counts
# Out:
#                     R15181  R15183_merged  R15207  R15274  R15394  R15395  \
# Gene
# ENSG00000000003.15     236            370     159     482     356     353
# ENSG00000000005.6        1              1       0       0       3       0
# ENSG00000000419.14     466            672     453     994     862     917
# ENSG00000000457.14     259            343     195     447     332     411
# ENSG00000000460.17     251            227     127     202     168     202
# ...                    ...            ...     ...     ...     ...     ...
# ENSG00000289714.1        0              0       0       0       0       0
# ENSG00000289715.1        0              0       0       0       0       0
# ENSG00000289716.1       53             64      29      21      17       5
# ENSG00000289718.1        0              0       0       0       0       0
# ENSG00000289719.1        0              1       0       4       1       1
#
# ...
